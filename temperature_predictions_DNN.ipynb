# %% [markdown]
# # Introduction to Dense Deep Neural Network for Temperature regression using satellite based land surface temperature.
#
# In this exercise, we introduce dense neural network layers for regression. We also provide an example of modeling using spatial datasets. We predict monthly air temperature using satellite based measurements of Land Surface Temperature (LST) from the MODIS sensor. The goal is to use the relationship between satellite and ground temperature meteorological stations measurements within a regression model. The ground temperature measurements were obtained from the Global Historical Climate Network (GHCN). To test the relationship, we predict air temperature for the month of January and July 2010 using MODIS raster layers. The MODIS layers are pre-processed monthly long term averages over the 2001-2012 time period.
#
#
# Interesting links:
#
# - modis data: https://terra.nasa.gov/about/terra-instruments/modis
#
# - tensorflow regression: https://www.tensorflow.org/tutorials/keras/regression
#
#
# # Set up google colab environment and load libraries

# %%
try: # try the following block of code
  import geopandas as gpd
except: # if the try block throws an error, run the following
  # !pip install geopandas # install geopandas
  import geopandas as gpd
  
try:
  import contextily as ctx # import
except:
  # !apt install libproj-dev proj-data proj-bin
  # !apt install libgeos-dev
  # !pip install cython
  # !pip install cartopy
  # !pip install contextily==1.0rc1 --no-use-pep517 --no-cache-dir
import contextily as ctx # library for providing background maps
import fiona # library for reading/writing GIS files, comes w/ geopandas
from shapely.geometry import Point, LineString, Polygon
# !pip install rasterio
# !pip install pyproj
#https://colab.research.google.com/github/bwsi-hadr/03-Intro-to-GIS/blob/master/03_Intro_to_GIS.ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rasterio in /usr/local/lib/python3.9/dist-packages (1.3.6)
# Requirement already satisfied: attrs in /usr/local/lib/python3.9/dist-packages (from rasterio) (22.2.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.9/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.9/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.9/dist-packages (from rasterio) (8.1.3)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.9/dist-packages (from rasterio) (1.22.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from rasterio) (63.4.3)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from rasterio) (1.4.7)
# Requirement already satisfied: affine in /usr/local/lib/python3.9/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from rasterio) (2022.12.7)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.9/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyproj in /usr/local/lib/python3.9/dist-packages (3.4.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from pyproj) (2022.12.7)

# %%
###### Library used in this script
#general use python packages and packages for data processing/visualization
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
import subprocess
import pandas as pd
import os, glob

#python packages related to geospatial data
from rasterio import plot
import geopandas as gpd
from osgeo import gdal
import rasterio
from cartopy import crs as ccrs
from pyproj import Proj
from osgeo import osr
from shapely.geometry import Point
from collections import OrderedDict

# modeling packages
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

# Deep learning packages
#import keras
#from keras.models import Sequential
#from keras.layers import *

#Keras import
from tensorflow import keras
from keras.models import Model
from keras.models import Sequential
#from keras.optimizers import Adam
from keras import layers
#from keras.layers import Input, Conv2D, Concatenate, Activation, MaxPool2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras import models
from tensorflow.keras.utils import plot_model
#from tensolayers.Dense import Dense

# %% [markdown]
# # Functions
# In the next part of the script, we declare all the functions used in the sripts. It is good practice to place functions at the beginning of a script or in an external source file. Here are the functions used:
#
# - create_dir_and_check_existence: create and output directory given a path. The output directory will be the working directory throughout the analysis.
#
# - model_predict_assessment: This function fits and predicts based on a input model (keras or sklearn) given a set of inputs. It also generates accuracy metrics to evaluate the performance.

# %%
################ NOW FUNCTIONS  ###################

##------------------
# Functions used in the script
##------------------

def create_dir_and_check_existence(path):
    #Create a new directory
    try:
        os.makedirs(path)
    except:
        print ("directory already exists")

def model_predict_assessement(model,
                              data_df,
                              selected_features,
                              selected_target,
                              prop=0.3,
                              random_seed=100,
                              epoch_val=None,
                              out_dir='.'):

    '''
    This function fits and predicts based on a input model (keras or sklearn) given a set of inputs. It also generates accuracy metrics to evaluate the performance.
    
    Input Arguments:

    model: a sklearn or keras model
    data_df: input data frame with relevant columns including features and target
    selected_features: set of input features to consider for the model (list from the data.frame)
    selected_target: selected target feature from the data.frame
    prop: proportion of input data.frame to keep for testing/holdout  
    random_seed: seed to use for reproducibility
    epoch_val: number of epoch to run the keras model, if None then it is assumed that the model is a sklearn model.
    out_dir: output directory

    Return Outputs:

    data_metrics_df: data.frame with columns including accuracy metrics (MAE, RMSE), months and model name used
    '''
    
    ##### Train/test split

    X_train, X_test, y_train, y_test = train_test_split(data_df[selected_features], 
                                                    data_df[selected_target], 
                                                    test_size=prop, 
                                                    random_state=random_seed)
    
    ############## Rescale inputs ######## 

    #### Scaling between 0-1 for continuous variables
    selected_continuous_var_names = selected_features
    # Data needs to be scaled to a small range like 0 to 1 for the neural
    # network to work well.
    scaler = MinMaxScaler(feature_range=(0, 1))
    ### need to select only the continuous var:
    scaled_training = scaler.fit_transform(X_train[selected_continuous_var_names])
    scaled_testing = scaler.transform(X_test[selected_continuous_var_names])

    ## Concatenate column-wise
    X_testing_df = pd.DataFrame(scaled_testing,columns=selected_continuous_var_names)
    X_training_df = pd.DataFrame(scaled_training, columns=selected_continuous_var_names)
    X_testing_df.to_csv(os.path.join(out_dir,
                    "X_testing_df_"+out_suffix+".csv"))
    X_training_df.to_csv(os.path.join(out_dir,
                    "X_training_df_"+out_suffix+".csv"))

    X = X_training_df.values
    Y = y_train #.values
    
    ############## Fit and predict model
    
    if(epoch_val is not None):
      history1_validation = model.fit(
                                     X,
                                     Y,
                                epochs=epoch_val,
      )
    else:
      model.fit(X, Y)

    y_pred_train = model.predict(X) # Note this is a fit!
    y_pred_test = model.predict(X_testing_df) # Note this is a test

    ########### Accuracy Assessment #######

    #from sklearn import metrics 

    mae_val_test = metrics.mean_absolute_error(y_test, y_pred_test) #MAE test
    rmse_val_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred_test)) #RMSE test
    mae_val_train = metrics.mean_absolute_error(y_train, y_pred_train) #MAE train
    rmse_val_train = np.sqrt(metrics.mean_squared_error(y_train, y_pred_train)) #RMSE train
    
    data = np.array([[mae_val_test,rmse_val_test],
                     [mae_val_train,rmse_val_train]])
    data_metrics_df = pd.DataFrame(data,columns=['mae','rmse'])
    data_metrics_df['test']=[1,0]
        
    return data_metrics_df

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Parameters and Arguments
#
# It is good practice to set all parameters and input arguments at the beginning of the script. This allows for better control and can make modifications of the scripts for other applications easier. Some arguments relate to path directories, input files and general parameters for use in the analyses (e.g. proportion of hold out).

# %%
############################################################################
#####  Parameters and argument set up ###########

#ARGS 1
in_dir = '/content/gdrive/MyDrive/Colab Notebooks/deep_learning_with_satellite_and_geospatial_data_course/intro_dense_neural_network/data/'

#ARGS 2
out_dir = '/content/gdrive/MyDrive/Colab Notebooks/deep_learning_with_satellite_and_geospatial_data_course/intro_dense_neural_network/'

#ARGS 3:
create_out_dir=True #create a new ouput dir if TRUE
#ARGS 4
out_suffix = "DNN_20230314" #output suffix for the files and ouptut folder
#ARGS 5
NA_value = -9999 # NA flag value
#ARG 6
ghcn_filename = "ghcn_or_tmax_covariates_06262012_OR83M.shp" # climate stations
#ARG 7
prop = 0.3
#ARG 8
random_seed= 42
#ARGS 9
#epsg 2991
crs_reg = "+proj=lcc +lat_1=43 +lat_2=45.5 +lat_0=41.75 +lon_0=-120.5 +x_0=400000 +y_0=0 +ellps=GRS80 +datum=NAD83 +units=m +no_defs"
#ARGS 10
infile_lst_month1 = "lst_mean_month1_rescaled.tif" 
#ARGS 11
infile_lst_month7 = "lst_mean_month7_rescaled.tif" 
#ARGS 12
epoch_n = 600

# %% [markdown]
# # Create output directory

# %%
################# START SCRIPT ###############################
######### PART 0: Set up the output dir ################

#set up the working directory
#Create output directory

if create_out_dir==True:
    out_dir_new = "output_data_"+out_suffix
    out_dir = os.path.join(out_dir,"outputs",out_dir_new)
    create_dir_and_check_existence(out_dir)
    os.chdir(out_dir)        #set working directory
else:
    os.chdir(out_dir) #use working dir defined earlier
# Out:
# directory already exists

# %%
print(out_dir)
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/deep_learning_with_satellite_and_geospatial_data_course/intro_dense_neural_network/outputs/output_data_DNN_20230314

# %% [markdown]
# # Workflow/pipeline
#
# There are multiple steps:
# 1. **Data Visualization and exploration**
# - Explore Land Surface Temperature and the meteorological stations provided
# 2. **Extraction of LST values from raster**
# - Extract LST values for January and July using station point locations.
# 3. **Processing stations data and LST**
# - Process stations data and LST values extract. This includes removing NAs and rescaling to Celsius degree units.
# 4. **Feature selection and feature processing**
# - select input features and target
# - rescale input features between 0-1
# - train-test split/hold out
# 5. **Building and training models**
# - build baseline model with Linear Regression model in sklearn
# - build dense neural network keras model
# - train models using training data
# 6. **Accuracy Assessment**
# - quick comparison
# - compare models and predict for July and January
# 7. **Conclusions**

# %% [markdown]
# # 1 Data visualization and exploration
#
# We visualize the remotely sensed LST images and the locations of meteorological stations within the Oregon study area. We use rasterio and geopandas to read in data in raster and shapefile formats respectively.

# %%
###########################################
### PART I: READ AND VISUALIZE DATA #######

data_gpd = gpd.read_file(os.path.join(in_dir,ghcn_filename)) 

## Extracting information from raster using raster io object
lst1 = rasterio.open(os.path.join(in_dir,infile_lst_month1))
lst7 = rasterio.open(os.path.join(in_dir,infile_lst_month7))
print(type(lst1))
print("Coordinate reference system: ",lst1.crs ) 
print(" Rows and columns: ", lst1.shape, "number of rows: ", lst1.height)  
data_gpd.head()
# Out:
# <class 'rasterio.io.DatasetReader'>
# Coordinate reference system:  EPSG:2991
#  Rows and columns:  (536, 745) number of rows:  536
#        station  year  month  day element  value mflag qflag sflag      lat  \
# 0  USC00350036  2010      1    1    TMAX  -9999   NaN   NaN   NaN  42.1761
# 1  USC00350036  2010      2    1    TMAX     61     0   NaN   NaN  42.1761
# 2  USC00350036  2010      3    1    TMAX    122     0   NaN   NaN  42.1761
# 3  USC00350036  2010      4    1    TMAX     44     0   NaN   NaN  42.1761
# 4  USC00350036  2010      5    1    TMAX  -9999   NaN   NaN   NaN  42.1761
#
#    ...  mmv_05  mmv_06 mmv_07 mmv_08 mmv_09 mmv_10  mmv_11  mmv_12      date  \
# 0  ...    90.0   118.0  210.0  198.0  169.0  101.0    48.0    20.0  20100101
# 1  ...    90.0   118.0  210.0  198.0  169.0  101.0    48.0    20.0  20100201
# 2  ...    90.0   118.0  210.0  198.0  169.0  101.0    48.0    20.0  20100301
# 3  ...    90.0   118.0  210.0  198.0  169.0  101.0    48.0    20.0  20100401
# 4  ...    90.0   118.0  210.0  198.0  169.0  101.0    48.0    20.0  20100501
#
#                        geometry
# 0  POINT (449915.447 47537.726)
# 1  POINT (449915.447 47537.726)
# 2  POINT (449915.447 47537.726)
# 3  POINT (449915.447 47537.726)
# 4  POINT (449915.447 47537.726)
#
# [5 rows x 74 columns]

# %% [markdown]
# It's also useful to get all the metadata information using the method profile or meta from the rasterio DatasetReader class. It returns a dictionary.

# %%
print(type(lst1))
lst1.meta
# Out:
# <class 'rasterio.io.DatasetReader'>
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': -3.3999999521443642e+38,
#  'width': 745,
#  'height': 536,
#  'count': 1,
#  'crs': CRS.from_epsg(2991),
#  'transform': Affine(926.5901740771812, 0.0, 33936.6328125,
#         0.0, -926.8062142899254, 519942.84375)}

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

f, ax = plt.subplots(1, 2,figsize=(15,15))
image_hidden1 = ax[0].imshow(lst1.read()[0],clim=(260,330))
divider1 = make_axes_locatable(ax[0])
cax1 = divider1.append_axes("right", size="5%", pad=0.05)
f.colorbar(image_hidden1, ax=ax[0],cax=cax1)
plot.show(lst1,title="LST January",clim=(260,330),ax=ax[0])


image_hidden2 = ax[1].imshow(lst7.read()[0],clim=(260,330))
divider2 = make_axes_locatable(ax[1])
cax2 = divider2.append_axes("right", size="5%", pad=0.05)
f.colorbar(image_hidden2, ax=ax[1],cax=cax2)
plot.show(lst7,title="LST July",clim=(260,330),ax=ax[1])

#Interesting links to look at:
#https://stackoverflow.com/questions/18195758/set-matplotlib-colorbar-size-to-match-graph
#https://courses.spatialthoughts.com/python-dataviz.html
#https://sigon.gitlab.io/post/2018-11-08-plot-raster-nodata-values/
#http://patrickgray.me/open-geo-tutorial/chapter_3_visualization.html
#https://geobgu.xyz/py/rasterio.html#summarizing-values
# Out:
# <AxesSubplot:title={'center':'LST July'}>

# %%
##### Combine raster layer and geogpanda layer

station_or = data_gpd.to_crs({'init': 'epsg:2991'}) #reproject to  match the  raster image

##### How to combine plots with rasterio package
fig, ax = plt.subplots(figsize=(10,10))
image_hidden1 = ax.imshow(lst1.read()[0],clim=(260,330))
divider = make_axes_locatable(ax) #necessary if figsize is set and it doesn't use the image ratio
cax = divider.append_axes("right", size="5%", pad=0.05)
fig.colorbar(image_hidden1, ax=ax,cax=cax)
rasterio.plot.show(lst1,ax=ax,
                          clim=(259.0,287.0),
                  title="Combine raster and points in a plot")
station_or.plot(ax=ax,
                marker="*",
                color="red",
                markersize=10)
# Out:
# /usr/local/lib/python3.9/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <AxesSubplot:title={'center':'Combine raster and points in a plot'}>

# %% [markdown]
# # 2 Extraction of LST values from raster
#
# Using meteorological station locations, we extract LST values using rasterio function 'sample' for the month of January and July. This requires an iterator with x,y coordinates matching the coordinate reference systems in the raster image.

# %%
#### Extract information from raster using coordinates
x_coord = station_or.geometry.x # pands.core.series.Series
y_coord = station_or.geometry.y
coords = [(x,y) for x, y in zip(x_coord, y_coord)]
print(type(coords))

station_or['LST1_val']= np.asarray([val for val in lst1.sample(xy=coords)])
station_or['LST7_val']= np.asarray([val for val in lst7.sample(xy=coords)])

station_or[['LST1_val','LST7_val']].head()
# Out:
# <class 'list'>
#      LST1_val    LST7_val
# 0  280.020691  318.788666
# 1  280.020691  318.788666
# 2  280.020691  318.788666
# 3  280.020691  318.788666
# 4  280.020691  318.788666

# %% [markdown]
# # 3 Processing stations data and LST
#
# The values extracted are in Kelvin degree and are repeated in each row. We convert values in degree C, and remove no data values (flag value is -9999). We compute averages at each weather station using the "groupby" pandas operator.The goal is to generate unique monthly LST values for each station. Note that we also need to rescale the GHCN network values to have comparable LST and ground measurements.

# %%
print("number of rows:",station_or.station.count(),", number of stations:",len(station_or.station.unique()))
# Convert Kelvin to celsius degree
station_or['LST1_val'] = station_or['LST1_val'] - 273.15 #modify January values
station_or['LST7_val'] = station_or['LST7_val'] - 273.15 #modify July values

#Remove NA values and select January and July
station_or_jan = station_or.loc[(station_or['month']==1) & (station_or['value']!=-9999)]
station_or_jul = station_or.loc[(station_or['month']==7) & (station_or['value']!=-9999)]

avg_jan_df = station_or_jan.groupby(['station'])['value','LST1_val','LST7_val','ELEV_SRTM','DISTOC'].mean()
avg_jul_df = station_or_jul.groupby(['station'])['value','LST1_val','LST7_val','ELEV_SRTM','DISTOC'].mean()

avg_jan_df['T1'] = avg_jan_df['value']/10
avg_jul_df['T7'] = avg_jul_df['value']/10

avg_jan_df = avg_jan_df.rename(columns={"LST1_val": "LST1", "LST7_val": "LST7"})
avg_jul_df = avg_jul_df.rename(columns={"LST1_val": "LST1", "LST7_val": "LST7"})
avg_jan_df.head()
# Out:
# number of rows: 67053 , number of stations: 186
# <ipython-input-13-e33142ad682c>:10: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_jan_df = station_or_jan.groupby(['station'])['value','LST1_val','LST7_val','ELEV_SRTM','DISTOC'].mean()
# <ipython-input-13-e33142ad682c>:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_jul_df = station_or_jul.groupby(['station'])['value','LST1_val','LST7_val','ELEV_SRTM','DISTOC'].mean()
#                   value      LST1       LST7  ELEV_SRTM         DISTOC  \
# station
# USC00350036   66.407407  6.870697  45.638672     1400.0  358792.750000
# USC00350118   75.428571  3.755188  45.133026     1297.0  350663.000000
# USC00350145  100.642857  4.750732  21.674225       78.0   26887.093750
# USC00350197   71.833333  2.684601  43.989899      921.0  257909.937500
# USC00350265   70.612903  3.665344  33.627228       80.0  261590.953125
#
#                     T1
# station
# USC00350036   6.640741
# USC00350118   7.542857
# USC00350145  10.064286
# USC00350197   7.183333
# USC00350265   7.061290

# %% [markdown]
# # 4 Feature selection and feature processing
#
# We select input and target features for use in the dense neural network (DNN). For better DNN convergence and results, features are typically rescaled or normalized/standardized. For this application, the rescaling is carried out to fit the values within a 0 to 1 interval. The same scaling is applied to the testing dataset as well.

# %%
################################################
###  PART III : Fit model and generate prediction

#selected_covariates_names_updated = selected_continuous_var_names + names_cat 
selected_features = ['LST1','ELEV_SRTM','DISTOC'] #selected features
selected_target = ['T1'] #selected dependent variables
## Split training and testing

#from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(avg_jan_df[selected_features], 
                                                    avg_jan_df[selected_target], 
                                                    test_size=prop, 
                                                    random_state=random_seed)
   
print(X_train.shape)

#### Scaling between 0-1 for continuous variables
selected_continuous_var_names = selected_features

scaler = MinMaxScaler(feature_range=(0, 1))
### need to select only the continuous var:
scaled_training = scaler.fit_transform(X_train[selected_continuous_var_names]) #array type
scaled_testing = scaler.transform(X_test[selected_continuous_var_names])

## Concatenate column-wise
X_testing_df = pd.DataFrame(scaled_testing,
                            columns=selected_continuous_var_names)

X_training_df = pd.DataFrame(scaled_training, 
                             columns=selected_continuous_var_names)

X_testing_df.to_csv(os.path.join(out_dir,
                    "X_testing_df_"+out_suffix+".csv"))

X_training_df.to_csv(os.path.join(out_dir,
                    "X_training_df_"+out_suffix+".csv"))

display(X_training_df.columns)
X = X_training_df.values
Y = y_train #.values

display(X.shape)
display(Y.shape)
# Out:
# (125, 3)
# Index(['LST1', 'ELEV_SRTM', 'DISTOC'], dtype='object')
# (125, 3)
# (125, 1)

# %% [markdown]
# # 5 Building and training models
#
# We build a dense neural network architecture using Keras and compare its performance to a baseline linear regression model.

# %% [markdown]
# ## 5.1 Baseline model: linear model using OLS
#
# We use 'sklearn' to instantiate a linear regression object. The model is fitted using the training data that was processed earlier.

# %%
#from sklearn.linear_model import LinearRegression
model_lregr = LinearRegression() #create/instantiate object used for linear regresssion
model_lregr.fit(X,Y) #fit model
# Out:
# LinearRegression()

# %% [markdown]
# ## 5.2 Dense Neural Network model
#
# We build a dense simple neural network using Keras sequential api. It is a five layers fully connected network with three hidden layers. All hidden layers use the relu activation. There are no activation for the final ouptut layer because we are performing a regression.
#
# We use the Means Square Error (MSE) as the loss function (error function being minimized) and Mean Absolute Error (MAE) for the metrics reported.

# %%
#NOTE INPUT SHOULD BE THE NUMBER OF VAR
#### Test with less number of input nodes: pruning
model_dnn = Sequential()
model_dnn.add(layers.Dense(4, input_dim=3, activation='relu'))
model_dnn.add(layers.Dense(10, activation='relu'))
model_dnn.add(layers.Dense(10, activation='relu'))
model_dnn.add(layers.Dense(1)) #scalar regression, end DNN without activation function as we are predicting continuous values

model_dnn.compile(optimizer="adam",
                  loss="mse",
                  metrics=["mae"])

model_dnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 16
#
#  dense_1 (Dense)             (None, 10)                50
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 187
# Trainable params: 187
# Non-trainable params: 0
# _________________________________________________________________

# %%
#epoch_n was set at the start of the script at 600
history_model = model_dnn.fit(
    X,
    Y,
    epochs=epoch_n,
    verbose=1
)
# Out:
# Epoch 1/600
# 4/4 [==============================] - 1s 8ms/step - loss: 78.4105 - mae: 8.3080
# Epoch 2/600
# 4/4 [==============================] - 0s 6ms/step - loss: 77.5217 - mae: 8.2538
# Epoch 3/600
# 4/4 [==============================] - 0s 6ms/step - loss: 76.6538 - mae: 8.1998
# Epoch 4/600
# 4/4 [==============================] - 0s 6ms/step - loss: 75.7860 - mae: 8.1465
# Epoch 5/600
# 4/4 [==============================] - 0s 5ms/step - loss: 74.9559 - mae: 8.0926
# Epoch 6/600
# 4/4 [==============================] - 0s 6ms/step - loss: 74.0836 - mae: 8.0383
# Epoch 7/600
# 4/4 [==============================] - 0s 5ms/step - loss: 73.2420 - mae: 7.9854
# Epoch 8/600
# 4/4 [==============================] - 0s 6ms/step - loss: 72.4198 - mae: 7.9319
# Epoch 9/600
# 4/4 [==============================] - 0s 5ms/step - loss: 71.5938 - mae: 7.8794
# Epoch 10/600
# 4/4 [==============================] - 0s 6ms/step - loss: 70.7933 - mae: 7.8259
# Epoch 11/600
# 4/4 [==============================] - 0s 6ms/step - loss: 69.9702 - mae: 7.7714
# Epoch 12/600
# 4/4 [==============================] - 0s 6ms/step - loss: 69.1189 - mae: 7.7151
# Epoch 13/600
# 4/4 [==============================] - 0s 6ms/step - loss: 68.2562 - mae: 7.6571
# Epoch 14/600
# 4/4 [==============================] - 0s 6ms/step - loss: 67.3670 - mae: 7.5966
# Epoch 15/600
# 4/4 [==============================] - 0s 6ms/step - loss: 66.4264 - mae: 7.5338
# Epoch 16/600
# 4/4 [==============================] - 0s 7ms/step - loss: 65.4579 - mae: 7.4686
# Epoch 17/600
# 4/4 [==============================] - 0s 6ms/step - loss: 64.4617 - mae: 7.3976
# Epoch 18/600
# 4/4 [==============================] - 0s 7ms/step - loss: 63.3810 - mae: 7.3234
# Epoch 19/600
# 4/4 [==============================] - 0s 4ms/step - loss: 62.2351 - mae: 7.2433
# Epoch 20/600
# 4/4 [==============================] - 0s 5ms/step - loss: 61.0278 - mae: 7.1577
# Epoch 21/600
# 4/4 [==============================] - 0s 6ms/step - loss: 59.7602 - mae: 7.0672
# Epoch 22/600
# 4/4 [==============================] - 0s 5ms/step - loss: 58.4438 - mae: 6.9707
# Epoch 23/600
# 4/4 [==============================] - 0s 5ms/step - loss: 57.0428 - mae: 6.8677
# Epoch 24/600
# 4/4 [==============================] - 0s 5ms/step - loss: 55.6179 - mae: 6.7627
# Epoch 25/600
# 4/4 [==============================] - 0s 7ms/step - loss: 54.0976 - mae: 6.6483
# Epoch 26/600
# 4/4 [==============================] - 0s 5ms/step - loss: 52.5725 - mae: 6.5319
# Epoch 27/600
# 4/4 [==============================] - 0s 6ms/step - loss: 50.9581 - mae: 6.4045
# Epoch 28/600
# 4/4 [==============================] - 0s 6ms/step - loss: 49.2930 - mae: 6.2728
# Epoch 29/600
# 4/4 [==============================] - 0s 7ms/step - loss: 47.6242 - mae: 6.1344
# Epoch 30/600
# 4/4 [==============================] - 0s 5ms/step - loss: 45.9117 - mae: 5.9903
# Epoch 31/600
# 4/4 [==============================] - 0s 5ms/step - loss: 44.2463 - mae: 5.8432
# Epoch 32/600
# 4/4 [==============================] - 0s 4ms/step - loss: 42.4689 - mae: 5.6934
# Epoch 33/600
# 4/4 [==============================] - 0s 4ms/step - loss: 40.7705 - mae: 5.5397
# Epoch 34/600
# 4/4 [==============================] - 0s 5ms/step - loss: 38.9339 - mae: 5.3836
# Epoch 35/600
# 4/4 [==============================] - 0s 5ms/step - loss: 37.2401 - mae: 5.2340
# Epoch 36/600
# 4/4 [==============================] - 0s 6ms/step - loss: 35.5181 - mae: 5.0778
# Epoch 37/600
# 4/4 [==============================] - 0s 4ms/step - loss: 33.7328 - mae: 4.9268
# Epoch 38/600
# 4/4 [==============================] - 0s 5ms/step - loss: 32.0617 - mae: 4.7726
# Epoch 39/600
# 4/4 [==============================] - 0s 4ms/step - loss: 30.3390 - mae: 4.6235
# Epoch 40/600
# 4/4 [==============================] - 0s 4ms/step - loss: 28.7322 - mae: 4.4704
# Epoch 41/600
# 4/4 [==============================] - 0s 4ms/step - loss: 27.0961 - mae: 4.3187
# Epoch 42/600
# 4/4 [==============================] - 0s 4ms/step - loss: 25.6296 - mae: 4.1745
# Epoch 43/600
# 4/4 [==============================] - 0s 5ms/step - loss: 24.2312 - mae: 4.0292
# Epoch 44/600
# 4/4 [==============================] - 0s 4ms/step - loss: 22.8392 - mae: 3.8926
# Epoch 45/600
# 4/4 [==============================] - 0s 4ms/step - loss: 21.6041 - mae: 3.7659
# Epoch 46/600
# 4/4 [==============================] - 0s 4ms/step - loss: 20.3813 - mae: 3.6434
# Epoch 47/600
# 4/4 [==============================] - 0s 4ms/step - loss: 19.3229 - mae: 3.5343
# Epoch 48/600
# 4/4 [==============================] - 0s 4ms/step - loss: 18.3479 - mae: 3.4411
# Epoch 49/600
# 4/4 [==============================] - 0s 4ms/step - loss: 17.4467 - mae: 3.3548
# Epoch 50/600
# 4/4 [==============================] - 0s 4ms/step - loss: 16.6994 - mae: 3.2872
# Epoch 51/600
# 4/4 [==============================] - 0s 6ms/step - loss: 15.9462 - mae: 3.2203
# Epoch 52/600
# 4/4 [==============================] - 0s 6ms/step - loss: 15.3531 - mae: 3.1782
# Epoch 53/600
# 4/4 [==============================] - 0s 5ms/step - loss: 14.8467 - mae: 3.1484
# Epoch 54/600
# 4/4 [==============================] - 0s 4ms/step - loss: 14.3844 - mae: 3.1270
# Epoch 55/600
# 4/4 [==============================] - 0s 4ms/step - loss: 14.0358 - mae: 3.1161
# Epoch 56/600
# 4/4 [==============================] - 0s 5ms/step - loss: 13.7116 - mae: 3.1051
# Epoch 57/600
# 4/4 [==============================] - 0s 5ms/step - loss: 13.4120 - mae: 3.0933
# Epoch 58/600
# 4/4 [==============================] - 0s 4ms/step - loss: 13.2002 - mae: 3.0871
# Epoch 59/600
# 4/4 [==============================] - 0s 5ms/step - loss: 13.0028 - mae: 3.0826
# Epoch 60/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.8312 - mae: 3.0728
# Epoch 61/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.7036 - mae: 3.0700
# Epoch 62/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.5830 - mae: 3.0663
# Epoch 63/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.4527 - mae: 3.0600
# Epoch 64/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.3556 - mae: 3.0556
# Epoch 65/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.2477 - mae: 3.0468
# Epoch 66/600
# 4/4 [==============================] - 0s 6ms/step - loss: 12.1220 - mae: 3.0351
# Epoch 67/600
# 4/4 [==============================] - 0s 4ms/step - loss: 12.0149 - mae: 3.0237
# Epoch 68/600
# 4/4 [==============================] - 0s 4ms/step - loss: 11.8903 - mae: 3.0099
# Epoch 69/600
# 4/4 [==============================] - 0s 4ms/step - loss: 11.7626 - mae: 2.9941
# Epoch 70/600
# 4/4 [==============================] - 0s 5ms/step - loss: 11.6369 - mae: 2.9780
# Epoch 71/600
# 4/4 [==============================] - 0s 5ms/step - loss: 11.4998 - mae: 2.9599
# Epoch 72/600
# 4/4 [==============================] - 0s 5ms/step - loss: 11.3511 - mae: 2.9393
# Epoch 73/600
# 4/4 [==============================] - 0s 6ms/step - loss: 11.2048 - mae: 2.9189
# Epoch 74/600
# 4/4 [==============================] - 0s 4ms/step - loss: 11.0498 - mae: 2.8965
# Epoch 75/600
# 4/4 [==============================] - 0s 5ms/step - loss: 10.8946 - mae: 2.8746
# Epoch 76/600
# 4/4 [==============================] - 0s 5ms/step - loss: 10.7392 - mae: 2.8531
# Epoch 77/600
# 4/4 [==============================] - 0s 4ms/step - loss: 10.5946 - mae: 2.8318
# Epoch 78/600
# 4/4 [==============================] - 0s 5ms/step - loss: 10.4467 - mae: 2.8113
# Epoch 79/600
# 4/4 [==============================] - 0s 4ms/step - loss: 10.3173 - mae: 2.7922
# Epoch 80/600
# 4/4 [==============================] - 0s 6ms/step - loss: 10.1755 - mae: 2.7723
# Epoch 81/600
# 4/4 [==============================] - 0s 4ms/step - loss: 10.0380 - mae: 2.7533
# Epoch 82/600
# 4/4 [==============================] - 0s 5ms/step - loss: 9.9009 - mae: 2.7345
# Epoch 83/600
# 4/4 [==============================] - 0s 5ms/step - loss: 9.7735 - mae: 2.7166
# Epoch 84/600
# 4/4 [==============================] - 0s 5ms/step - loss: 9.6431 - mae: 2.7000
# Epoch 85/600
# 4/4 [==============================] - 0s 5ms/step - loss: 9.4994 - mae: 2.6797
# Epoch 86/600
# 4/4 [==============================] - 0s 5ms/step - loss: 9.3644 - mae: 2.6597
# Epoch 87/600
# 4/4 [==============================] - 0s 6ms/step - loss: 9.2356 - mae: 2.6400
# Epoch 88/600
# 4/4 [==============================] - 0s 6ms/step - loss: 9.1032 - mae: 2.6212
# Epoch 89/600
# 4/4 [==============================] - 0s 6ms/step - loss: 8.9682 - mae: 2.6021
# Epoch 90/600
# 4/4 [==============================] - 0s 4ms/step - loss: 8.8317 - mae: 2.5824
# Epoch 91/600
# 4/4 [==============================] - 0s 4ms/step - loss: 8.7016 - mae: 2.5619
# Epoch 92/600
# 4/4 [==============================] - 0s 6ms/step - loss: 8.5742 - mae: 2.5425
# Epoch 93/600
# 4/4 [==============================] - 0s 4ms/step - loss: 8.4325 - mae: 2.5213
# Epoch 94/600
# 4/4 [==============================] - 0s 5ms/step - loss: 8.3042 - mae: 2.5005
# Epoch 95/600
# 4/4 [==============================] - 0s 4ms/step - loss: 8.1713 - mae: 2.4804
# Epoch 96/600
# 4/4 [==============================] - 0s 4ms/step - loss: 8.0507 - mae: 2.4629
# Epoch 97/600
# 4/4 [==============================] - 0s 5ms/step - loss: 7.9072 - mae: 2.4402
# Epoch 98/600
# 4/4 [==============================] - 0s 5ms/step - loss: 7.7764 - mae: 2.4183
# Epoch 99/600
# 4/4 [==============================] - 0s 5ms/step - loss: 7.6459 - mae: 2.3957
# Epoch 100/600
# 4/4 [==============================] - 0s 4ms/step - loss: 7.5092 - mae: 2.3728
# Epoch 101/600
# 4/4 [==============================] - 0s 4ms/step - loss: 7.3869 - mae: 2.3523
# Epoch 102/600
# 4/4 [==============================] - 0s 4ms/step - loss: 7.2585 - mae: 2.3307
# Epoch 103/600
# 4/4 [==============================] - 0s 4ms/step - loss: 7.1237 - mae: 2.3079
# Epoch 104/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.9971 - mae: 2.2865
# Epoch 105/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.8709 - mae: 2.2636
# Epoch 106/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.7454 - mae: 2.2409
# Epoch 107/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.6175 - mae: 2.2171
# Epoch 108/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.4918 - mae: 2.1940
# Epoch 109/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.3670 - mae: 2.1701
# Epoch 110/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2455 - mae: 2.1474
# Epoch 111/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.1318 - mae: 2.1257
# Epoch 112/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.0082 - mae: 2.1018
# Epoch 113/600
# 4/4 [==============================] - 0s 4ms/step - loss: 5.8834 - mae: 2.0757
# Epoch 114/600
# 4/4 [==============================] - 0s 4ms/step - loss: 5.7662 - mae: 2.0522
# Epoch 115/600
# 4/4 [==============================] - 0s 4ms/step - loss: 5.6495 - mae: 2.0286
# Epoch 116/600
# 4/4 [==============================] - 0s 4ms/step - loss: 5.5367 - mae: 2.0047
# Epoch 117/600
# 4/4 [==============================] - 0s 4ms/step - loss: 5.4246 - mae: 1.9806
# Epoch 118/600
# 4/4 [==============================] - 0s 10ms/step - loss: 5.3176 - mae: 1.9584
# Epoch 119/600
# 4/4 [==============================] - 0s 6ms/step - loss: 5.2050 - mae: 1.9339
# Epoch 120/600
# 4/4 [==============================] - 0s 4ms/step - loss: 5.0949 - mae: 1.9088
# Epoch 121/600
# 4/4 [==============================] - 0s 4ms/step - loss: 4.9813 - mae: 1.8857
# Epoch 122/600
# 4/4 [==============================] - 0s 5ms/step - loss: 4.8653 - mae: 1.8584
# Epoch 123/600
# 4/4 [==============================] - 0s 4ms/step - loss: 4.7166 - mae: 1.8211
# Epoch 124/600
# 4/4 [==============================] - 0s 4ms/step - loss: 4.5588 - mae: 1.7828
# Epoch 125/600
# 4/4 [==============================] - 0s 5ms/step - loss: 4.3592 - mae: 1.7293
# Epoch 126/600
# 4/4 [==============================] - 0s 4ms/step - loss: 4.1697 - mae: 1.6745
# Epoch 127/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.9570 - mae: 1.6125
# Epoch 128/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.7588 - mae: 1.5583
# Epoch 129/600
# 4/4 [==============================] - 0s 4ms/step - loss: 3.6195 - mae: 1.5188
# Epoch 130/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.4756 - mae: 1.4792
# Epoch 131/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.3629 - mae: 1.4473
# Epoch 132/600
# 4/4 [==============================] - 0s 6ms/step - loss: 3.2601 - mae: 1.4168
# Epoch 133/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.1596 - mae: 1.3833
# Epoch 134/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.0794 - mae: 1.3579
# Epoch 135/600
# 4/4 [==============================] - 0s 5ms/step - loss: 3.0053 - mae: 1.3306
# Epoch 136/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.9333 - mae: 1.3073
# Epoch 137/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.8778 - mae: 1.2890
# Epoch 138/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.8203 - mae: 1.2696
# Epoch 139/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7767 - mae: 1.2550
# Epoch 140/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7322 - mae: 1.2395
# Epoch 141/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6993 - mae: 1.2268
# Epoch 142/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6668 - mae: 1.2141
# Epoch 143/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6364 - mae: 1.2037
# Epoch 144/600
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6143 - mae: 1.1950
# Epoch 145/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5939 - mae: 1.1925
# Epoch 146/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5724 - mae: 1.1859
# Epoch 147/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5580 - mae: 1.1841
# Epoch 148/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5462 - mae: 1.1821
# Epoch 149/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5294 - mae: 1.1788
# Epoch 150/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5231 - mae: 1.1777
# Epoch 151/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5066 - mae: 1.1742
# Epoch 152/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5029 - mae: 1.1724
# Epoch 153/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4938 - mae: 1.1708
# Epoch 154/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4883 - mae: 1.1717
# Epoch 155/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4801 - mae: 1.1711
# Epoch 156/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4777 - mae: 1.1728
# Epoch 157/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4789 - mae: 1.1757
# Epoch 158/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4709 - mae: 1.1748
# Epoch 159/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4685 - mae: 1.1719
# Epoch 160/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4631 - mae: 1.1690
# Epoch 161/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4616 - mae: 1.1691
# Epoch 162/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4586 - mae: 1.1687
# Epoch 163/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.4554 - mae: 1.1713
# Epoch 164/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4532 - mae: 1.1730
# Epoch 165/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4536 - mae: 1.1738
# Epoch 166/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4511 - mae: 1.1733
# Epoch 167/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4510 - mae: 1.1704
# Epoch 168/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4466 - mae: 1.1685
# Epoch 169/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4467 - mae: 1.1685
# Epoch 170/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4451 - mae: 1.1695
# Epoch 171/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4415 - mae: 1.1711
# Epoch 172/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4499 - mae: 1.1753
# Epoch 173/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4414 - mae: 1.1725
# Epoch 174/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4377 - mae: 1.1710
# Epoch 175/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4361 - mae: 1.1707
# Epoch 176/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4344 - mae: 1.1706
# Epoch 177/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4365 - mae: 1.1702
# Epoch 178/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4367 - mae: 1.1678
# Epoch 179/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4325 - mae: 1.1684
# Epoch 180/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4281 - mae: 1.1699
# Epoch 181/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4319 - mae: 1.1713
# Epoch 182/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4299 - mae: 1.1726
# Epoch 183/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4279 - mae: 1.1731
# Epoch 184/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4268 - mae: 1.1714
# Epoch 185/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4274 - mae: 1.1688
# Epoch 186/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4217 - mae: 1.1678
# Epoch 187/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4238 - mae: 1.1701
# Epoch 188/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4184 - mae: 1.1703
# Epoch 189/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4244 - mae: 1.1718
# Epoch 190/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4160 - mae: 1.1690
# Epoch 191/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4176 - mae: 1.1678
# Epoch 192/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4131 - mae: 1.1657
# Epoch 193/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4113 - mae: 1.1656
# Epoch 194/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4112 - mae: 1.1673
# Epoch 195/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4095 - mae: 1.1679
# Epoch 196/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4080 - mae: 1.1689
# Epoch 197/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4050 - mae: 1.1684
# Epoch 198/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4064 - mae: 1.1673
# Epoch 199/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4070 - mae: 1.1676
# Epoch 200/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4003 - mae: 1.1667
# Epoch 201/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4060 - mae: 1.1681
# Epoch 202/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3988 - mae: 1.1651
# Epoch 203/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3988 - mae: 1.1633
# Epoch 204/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3966 - mae: 1.1628
# Epoch 205/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3934 - mae: 1.1637
# Epoch 206/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3913 - mae: 1.1642
# Epoch 207/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3935 - mae: 1.1653
# Epoch 208/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3937 - mae: 1.1685
# Epoch 209/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3903 - mae: 1.1669
# Epoch 210/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3906 - mae: 1.1634
# Epoch 211/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3836 - mae: 1.1616
# Epoch 212/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3833 - mae: 1.1627
# Epoch 213/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3821 - mae: 1.1627
# Epoch 214/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.3774 - mae: 1.1606
# Epoch 215/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3772 - mae: 1.1591
# Epoch 216/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3707 - mae: 1.1591
# Epoch 217/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3689 - mae: 1.1586
# Epoch 218/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3672 - mae: 1.1583
# Epoch 219/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3620 - mae: 1.1582
# Epoch 220/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3604 - mae: 1.1579
# Epoch 221/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3582 - mae: 1.1559
# Epoch 222/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3601 - mae: 1.1542
# Epoch 223/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3542 - mae: 1.1525
# Epoch 224/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3542 - mae: 1.1543
# Epoch 225/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3478 - mae: 1.1520
# Epoch 226/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3488 - mae: 1.1533
# Epoch 227/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3426 - mae: 1.1529
# Epoch 228/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3397 - mae: 1.1514
# Epoch 229/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3332 - mae: 1.1485
# Epoch 230/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3308 - mae: 1.1469
# Epoch 231/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3305 - mae: 1.1457
# Epoch 232/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3272 - mae: 1.1447
# Epoch 233/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3297 - mae: 1.1446
# Epoch 234/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3310 - mae: 1.1453
# Epoch 235/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3258 - mae: 1.1460
# Epoch 236/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3205 - mae: 1.1438
# Epoch 237/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3187 - mae: 1.1423
# Epoch 238/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3259 - mae: 1.1422
# Epoch 239/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3177 - mae: 1.1396
# Epoch 240/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3169 - mae: 1.1409
# Epoch 241/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.3149 - mae: 1.1413
# Epoch 242/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3124 - mae: 1.1411
# Epoch 243/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3099 - mae: 1.1396
# Epoch 244/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3113 - mae: 1.1397
# Epoch 245/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3063 - mae: 1.1379
# Epoch 246/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3038 - mae: 1.1353
# Epoch 247/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3034 - mae: 1.1340
# Epoch 248/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3015 - mae: 1.1334
# Epoch 249/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3027 - mae: 1.1340
# Epoch 250/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2998 - mae: 1.1347
# Epoch 251/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2991 - mae: 1.1341
# Epoch 252/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2969 - mae: 1.1331
# Epoch 253/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2968 - mae: 1.1339
# Epoch 254/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2976 - mae: 1.1329
# Epoch 255/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2946 - mae: 1.1321
# Epoch 256/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2968 - mae: 1.1331
# Epoch 257/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2913 - mae: 1.1317
# Epoch 258/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2968 - mae: 1.1308
# Epoch 259/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2927 - mae: 1.1298
# Epoch 260/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2896 - mae: 1.1294
# Epoch 261/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2881 - mae: 1.1291
# Epoch 262/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2866 - mae: 1.1285
# Epoch 263/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2876 - mae: 1.1287
# Epoch 264/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2860 - mae: 1.1276
# Epoch 265/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2837 - mae: 1.1266
# Epoch 266/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2828 - mae: 1.1256
# Epoch 267/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2851 - mae: 1.1261
# Epoch 268/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2805 - mae: 1.1268
# Epoch 269/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2788 - mae: 1.1254
# Epoch 270/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2765 - mae: 1.1241
# Epoch 271/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2791 - mae: 1.1247
# Epoch 272/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2742 - mae: 1.1221
# Epoch 273/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2738 - mae: 1.1223
# Epoch 274/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2734 - mae: 1.1236
# Epoch 275/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2725 - mae: 1.1237
# Epoch 276/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2747 - mae: 1.1229
# Epoch 277/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2682 - mae: 1.1203
# Epoch 278/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2670 - mae: 1.1201
# Epoch 279/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2743 - mae: 1.1203
# Epoch 280/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2647 - mae: 1.1170
# Epoch 281/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2640 - mae: 1.1177
# Epoch 282/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2719 - mae: 1.1232
# Epoch 283/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2627 - mae: 1.1200
# Epoch 284/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2630 - mae: 1.1188
# Epoch 285/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2608 - mae: 1.1168
# Epoch 286/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2589 - mae: 1.1151
# Epoch 287/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2579 - mae: 1.1149
# Epoch 288/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2606 - mae: 1.1164
# Epoch 289/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2572 - mae: 1.1158
# Epoch 290/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2603 - mae: 1.1171
# Epoch 291/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2604 - mae: 1.1172
# Epoch 292/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2549 - mae: 1.1143
# Epoch 293/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2537 - mae: 1.1148
# Epoch 294/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2516 - mae: 1.1142
# Epoch 295/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2517 - mae: 1.1141
# Epoch 296/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2521 - mae: 1.1141
# Epoch 297/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2513 - mae: 1.1131
# Epoch 298/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2483 - mae: 1.1127
# Epoch 299/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2521 - mae: 1.1153
# Epoch 300/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2507 - mae: 1.1147
# Epoch 301/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2463 - mae: 1.1125
# Epoch 302/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2445 - mae: 1.1118
# Epoch 303/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2458 - mae: 1.1120
# Epoch 304/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2474 - mae: 1.1115
# Epoch 305/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2443 - mae: 1.1111
# Epoch 306/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2446 - mae: 1.1123
# Epoch 307/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2415 - mae: 1.1121
# Epoch 308/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2391 - mae: 1.1109
# Epoch 309/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2425 - mae: 1.1121
# Epoch 310/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2364 - mae: 1.1095
# Epoch 311/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2352 - mae: 1.1080
# Epoch 312/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2329 - mae: 1.1069
# Epoch 313/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2324 - mae: 1.1063
# Epoch 314/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2338 - mae: 1.1079
# Epoch 315/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2329 - mae: 1.1076
# Epoch 316/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2276 - mae: 1.1051
# Epoch 317/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2263 - mae: 1.1052
# Epoch 318/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2250 - mae: 1.1047
# Epoch 319/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2292 - mae: 1.1063
# Epoch 320/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2241 - mae: 1.1049
# Epoch 321/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2220 - mae: 1.1038
# Epoch 322/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2277 - mae: 1.1038
# Epoch 323/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2206 - mae: 1.1015
# Epoch 324/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2235 - mae: 1.1036
# Epoch 325/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2202 - mae: 1.1033
# Epoch 326/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2207 - mae: 1.1030
# Epoch 327/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2233 - mae: 1.1042
# Epoch 328/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2169 - mae: 1.1033
# Epoch 329/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2184 - mae: 1.1028
# Epoch 330/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2158 - mae: 1.1009
# Epoch 331/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2166 - mae: 1.1003
# Epoch 332/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2143 - mae: 1.0993
# Epoch 333/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2138 - mae: 1.0998
# Epoch 334/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2140 - mae: 1.1005
# Epoch 335/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2122 - mae: 1.1010
# Epoch 336/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2124 - mae: 1.1003
# Epoch 337/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2152 - mae: 1.1020
# Epoch 338/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2109 - mae: 1.1009
# Epoch 339/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2101 - mae: 1.1001
# Epoch 340/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2079 - mae: 1.0980
# Epoch 341/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2139 - mae: 1.0972
# Epoch 342/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2129 - mae: 1.0992
# Epoch 343/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2073 - mae: 1.0983
# Epoch 344/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2080 - mae: 1.0991
# Epoch 345/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2052 - mae: 1.0975
# Epoch 346/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2067 - mae: 1.0992
# Epoch 347/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2180 - mae: 1.1027
# Epoch 348/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2035 - mae: 1.0995
# Epoch 349/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2178 - mae: 1.0987
# Epoch 350/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2095 - mae: 1.0935
# Epoch 351/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2038 - mae: 1.0936
# Epoch 352/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2046 - mae: 1.0976
# Epoch 353/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2086 - mae: 1.1010
# Epoch 354/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2021 - mae: 1.0994
# Epoch 355/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2001 - mae: 1.0978
# Epoch 356/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1999 - mae: 1.0953
# Epoch 357/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1987 - mae: 1.0935
# Epoch 358/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2013 - mae: 1.0937
# Epoch 359/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1976 - mae: 1.0930
# Epoch 360/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2028 - mae: 1.0969
# Epoch 361/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2009 - mae: 1.0964
# Epoch 362/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1965 - mae: 1.0962
# Epoch 363/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1968 - mae: 1.0961
# Epoch 364/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1984 - mae: 1.0966
# Epoch 365/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1967 - mae: 1.0926
# Epoch 366/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1996 - mae: 1.0934
# Epoch 367/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1931 - mae: 1.0944
# Epoch 368/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1963 - mae: 1.0951
# Epoch 369/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1912 - mae: 1.0923
# Epoch 370/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1903 - mae: 1.0922
# Epoch 371/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1937 - mae: 1.0947
# Epoch 372/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1896 - mae: 1.0937
# Epoch 373/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1888 - mae: 1.0932
# Epoch 374/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1912 - mae: 1.0918
# Epoch 375/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1913 - mae: 1.0931
# Epoch 376/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1876 - mae: 1.0920
# Epoch 377/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1876 - mae: 1.0925
# Epoch 378/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1897 - mae: 1.0938
# Epoch 379/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1882 - mae: 1.0921
# Epoch 380/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.1870 - mae: 1.0909
# Epoch 381/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1846 - mae: 1.0900
# Epoch 382/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1881 - mae: 1.0897
# Epoch 383/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1840 - mae: 1.0902
# Epoch 384/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1831 - mae: 1.0901
# Epoch 385/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1827 - mae: 1.0907
# Epoch 386/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1816 - mae: 1.0912
# Epoch 387/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1831 - mae: 1.0909
# Epoch 388/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1829 - mae: 1.0899
# Epoch 389/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1819 - mae: 1.0902
# Epoch 390/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1796 - mae: 1.0894
# Epoch 391/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1789 - mae: 1.0902
# Epoch 392/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1780 - mae: 1.0896
# Epoch 393/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1809 - mae: 1.0898
# Epoch 394/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1899 - mae: 1.0883
# Epoch 395/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1789 - mae: 1.0848
# Epoch 396/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1763 - mae: 1.0882
# Epoch 397/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1783 - mae: 1.0894
# Epoch 398/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1775 - mae: 1.0912
# Epoch 399/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1749 - mae: 1.0896
# Epoch 400/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1764 - mae: 1.0899
# Epoch 401/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1764 - mae: 1.0886
# Epoch 402/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1732 - mae: 1.0858
# Epoch 403/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1739 - mae: 1.0867
# Epoch 404/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1733 - mae: 1.0873
# Epoch 405/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1745 - mae: 1.0847
# Epoch 406/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1729 - mae: 1.0867
# Epoch 407/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1713 - mae: 1.0866
# Epoch 408/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1703 - mae: 1.0862
# Epoch 409/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1697 - mae: 1.0866
# Epoch 410/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1720 - mae: 1.0881
# Epoch 411/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1689 - mae: 1.0861
# Epoch 412/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1683 - mae: 1.0846
# Epoch 413/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1697 - mae: 1.0862
# Epoch 414/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1670 - mae: 1.0851
# Epoch 415/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1686 - mae: 1.0832
# Epoch 416/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1666 - mae: 1.0833
# Epoch 417/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1667 - mae: 1.0842
# Epoch 418/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1663 - mae: 1.0852
# Epoch 419/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1645 - mae: 1.0838
# Epoch 420/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1638 - mae: 1.0839
# Epoch 421/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1661 - mae: 1.0837
# Epoch 422/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1642 - mae: 1.0847
# Epoch 423/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1617 - mae: 1.0847
# Epoch 424/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1605 - mae: 1.0839
# Epoch 425/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1628 - mae: 1.0843
# Epoch 426/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1619 - mae: 1.0828
# Epoch 427/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1609 - mae: 1.0820
# Epoch 428/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1601 - mae: 1.0838
# Epoch 429/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1608 - mae: 1.0839
# Epoch 430/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1585 - mae: 1.0833
# Epoch 431/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1584 - mae: 1.0821
# Epoch 432/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1571 - mae: 1.0813
# Epoch 433/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1604 - mae: 1.0818
# Epoch 434/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1580 - mae: 1.0842
# Epoch 435/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1620 - mae: 1.0833
# Epoch 436/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1555 - mae: 1.0800
# Epoch 437/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1546 - mae: 1.0801
# Epoch 438/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1614 - mae: 1.0839
# Epoch 439/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1538 - mae: 1.0820
# Epoch 440/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1531 - mae: 1.0816
# Epoch 441/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1554 - mae: 1.0794
# Epoch 442/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1519 - mae: 1.0788
# Epoch 443/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1555 - mae: 1.0820
# Epoch 444/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1520 - mae: 1.0823
# Epoch 445/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1521 - mae: 1.0821
# Epoch 446/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1498 - mae: 1.0808
# Epoch 447/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1545 - mae: 1.0791
# Epoch 448/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1572 - mae: 1.0824
# Epoch 449/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1506 - mae: 1.0808
# Epoch 450/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1526 - mae: 1.0795
# Epoch 451/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1491 - mae: 1.0776
# Epoch 452/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1478 - mae: 1.0783
# Epoch 453/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1478 - mae: 1.0795
# Epoch 454/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1481 - mae: 1.0822
# Epoch 455/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1430 - mae: 1.0798
# Epoch 456/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1431 - mae: 1.0777
# Epoch 457/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1440 - mae: 1.0762
# Epoch 458/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1484 - mae: 1.0796
# Epoch 459/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1411 - mae: 1.0790
# Epoch 460/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1410 - mae: 1.0788
# Epoch 461/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1410 - mae: 1.0775
# Epoch 462/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1431 - mae: 1.0778
# Epoch 463/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1393 - mae: 1.0759
# Epoch 464/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1409 - mae: 1.0779
# Epoch 465/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1417 - mae: 1.0808
# Epoch 466/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1415 - mae: 1.0811
# Epoch 467/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1429 - mae: 1.0769
# Epoch 468/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1363 - mae: 1.0760
# Epoch 469/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1433 - mae: 1.0787
# Epoch 470/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1449 - mae: 1.0748
# Epoch 471/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1344 - mae: 1.0744
# Epoch 472/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1332 - mae: 1.0755
# Epoch 473/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1338 - mae: 1.0760
# Epoch 474/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1336 - mae: 1.0768
# Epoch 475/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1318 - mae: 1.0760
# Epoch 476/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1305 - mae: 1.0751
# Epoch 477/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1316 - mae: 1.0748
# Epoch 478/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1316 - mae: 1.0758
# Epoch 479/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1376 - mae: 1.0769
# Epoch 480/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1289 - mae: 1.0727
# Epoch 481/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1271 - mae: 1.0732
# Epoch 482/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1298 - mae: 1.0728
# Epoch 483/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1260 - mae: 1.0721
# Epoch 484/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1265 - mae: 1.0736
# Epoch 485/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1265 - mae: 1.0757
# Epoch 486/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1314 - mae: 1.0784
# Epoch 487/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1256 - mae: 1.0759
# Epoch 488/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1336 - mae: 1.0723
# Epoch 489/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1282 - mae: 1.0709
# Epoch 490/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1239 - mae: 1.0724
# Epoch 491/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1222 - mae: 1.0720
# Epoch 492/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1248 - mae: 1.0753
# Epoch 493/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1218 - mae: 1.0742
# Epoch 494/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1213 - mae: 1.0723
# Epoch 495/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1267 - mae: 1.0719
# Epoch 496/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1230 - mae: 1.0696
# Epoch 497/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1245 - mae: 1.0740
# Epoch 498/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1198 - mae: 1.0743
# Epoch 499/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1229 - mae: 1.0709
# Epoch 500/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1190 - mae: 1.0694
# Epoch 501/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1196 - mae: 1.0697
# Epoch 502/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1174 - mae: 1.0711
# Epoch 503/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1204 - mae: 1.0730
# Epoch 504/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1276 - mae: 1.0752
# Epoch 505/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1176 - mae: 1.0696
# Epoch 506/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1150 - mae: 1.0705
# Epoch 507/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1148 - mae: 1.0705
# Epoch 508/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1140 - mae: 1.0694
# Epoch 509/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1172 - mae: 1.0706
# Epoch 510/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1232 - mae: 1.0738
# Epoch 511/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1197 - mae: 1.0715
# Epoch 512/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1175 - mae: 1.0664
# Epoch 513/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1211 - mae: 1.0724
# Epoch 514/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1133 - mae: 1.0713
# Epoch 515/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1192 - mae: 1.0740
# Epoch 516/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1090 - mae: 1.0700
# Epoch 517/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1114 - mae: 1.0670
# Epoch 518/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1138 - mae: 1.0669
# Epoch 519/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1124 - mae: 1.0678
# Epoch 520/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1155 - mae: 1.0707
# Epoch 521/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1140 - mae: 1.0713
# Epoch 522/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1131 - mae: 1.0684
# Epoch 523/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1093 - mae: 1.0686
# Epoch 524/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1110 - mae: 1.0667
# Epoch 525/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1058 - mae: 1.0654
# Epoch 526/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1048 - mae: 1.0666
# Epoch 527/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1049 - mae: 1.0681
# Epoch 528/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1149 - mae: 1.0692
# Epoch 529/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1053 - mae: 1.0663
# Epoch 530/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1037 - mae: 1.0677
# Epoch 531/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1058 - mae: 1.0686
# Epoch 532/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1021 - mae: 1.0675
# Epoch 533/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1028 - mae: 1.0658
# Epoch 534/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1022 - mae: 1.0652
# Epoch 535/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1010 - mae: 1.0640
# Epoch 536/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1002 - mae: 1.0640
# Epoch 537/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1050 - mae: 1.0672
# Epoch 538/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1026 - mae: 1.0681
# Epoch 539/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0986 - mae: 1.0655
# Epoch 540/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0997 - mae: 1.0661
# Epoch 541/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0980 - mae: 1.0657
# Epoch 542/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0962 - mae: 1.0633
# Epoch 543/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1199 - mae: 1.0669
# Epoch 544/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0985 - mae: 1.0628
# Epoch 545/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0939 - mae: 1.0616
# Epoch 546/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0965 - mae: 1.0672
# Epoch 547/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1104 - mae: 1.0722
# Epoch 548/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1015 - mae: 1.0686
# Epoch 549/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1015 - mae: 1.0621
# Epoch 550/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1045 - mae: 1.0623
# Epoch 551/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0976 - mae: 1.0618
# Epoch 552/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0915 - mae: 1.0634
# Epoch 553/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0932 - mae: 1.0655
# Epoch 554/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0973 - mae: 1.0661
# Epoch 555/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0919 - mae: 1.0640
# Epoch 556/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0907 - mae: 1.0634
# Epoch 557/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0914 - mae: 1.0629
# Epoch 558/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0923 - mae: 1.0628
# Epoch 559/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0923 - mae: 1.0625
# Epoch 560/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0912 - mae: 1.0628
# Epoch 561/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0889 - mae: 1.0623
# Epoch 562/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0896 - mae: 1.0631
# Epoch 563/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0917 - mae: 1.0612
# Epoch 564/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0886 - mae: 1.0606
# Epoch 565/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0882 - mae: 1.0613
# Epoch 566/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0892 - mae: 1.0626
# Epoch 567/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0944 - mae: 1.0612
# Epoch 568/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0848 - mae: 1.0600
# Epoch 569/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0873 - mae: 1.0619
# Epoch 570/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0901 - mae: 1.0646
# Epoch 571/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0897 - mae: 1.0630
# Epoch 572/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0883 - mae: 1.0614
# Epoch 573/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0879 - mae: 1.0597
# Epoch 574/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0901 - mae: 1.0615
# Epoch 575/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0859 - mae: 1.0619
# Epoch 576/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0885 - mae: 1.0643
# Epoch 577/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0846 - mae: 1.0621
# Epoch 578/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0816 - mae: 1.0601
# Epoch 579/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0805 - mae: 1.0595
# Epoch 580/600
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0830 - mae: 1.0594
# Epoch 581/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0799 - mae: 1.0588
# Epoch 582/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0798 - mae: 1.0594
# Epoch 583/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0809 - mae: 1.0602
# Epoch 584/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0837 - mae: 1.0617
# Epoch 585/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0785 - mae: 1.0603
# Epoch 586/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0770 - mae: 1.0578
# Epoch 587/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0831 - mae: 1.0579
# Epoch 588/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0783 - mae: 1.0576
# Epoch 589/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0892 - mae: 1.0598
# Epoch 590/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0785 - mae: 1.0612
# Epoch 591/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0770 - mae: 1.0604
# Epoch 592/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0761 - mae: 1.0588
# Epoch 593/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0753 - mae: 1.0574
# Epoch 594/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0769 - mae: 1.0581
# Epoch 595/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0784 - mae: 1.0572
# Epoch 596/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0778 - mae: 1.0576
# Epoch 597/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0769 - mae: 1.0600
# Epoch 598/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0779 - mae: 1.0597
# Epoch 599/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0809 - mae: 1.0606
# Epoch 600/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0732 - mae: 1.0573

# %%
# Save model fit history to data frame
loss_acc_fit_model_dnn_df = pd.DataFrame(history_model.history)
loss_acc_fit_model_dnn_df.to_csv("loss_acc_fit_model_dnn_df.csv")
loss_acc_fit_model_dnn_df
# Out:
#           loss       mae
# 0    78.410454  8.307960
# 1    77.521729  8.253761
# 2    76.653763  8.199773
# 3    75.785980  8.146460
# 4    74.955910  8.092607
# ..         ...       ...
# 595   2.077756  1.057637
# 596   2.076896  1.059981
# 597   2.077942  1.059729
# 598   2.080876  1.060635
# 599   2.073227  1.057303
#
# [600 rows x 2 columns]

# %%
# Plot fit history
fig, ax = plt.subplots()
ax.plot(range(1,epoch_n+1),loss_acc_fit_model_dnn_df['loss'],
        color="red",label="training")
ax.legend()
# Add title and axis names
ax.set_title('Loss by echo during training')
ax.set_xlabel('epoch')
ax.set_ylabel('loss (mse)')
# Out:
# Text(0, 0.5, 'loss (mse)')

# %% [markdown]
# # 6 Accuracy assessment and model comparioson
#
# We will use the RMSE and MAE to assess model performance for both January and July predictions.

# %% [markdown]
# ## 6.1. Quick comparison
#
# Using the model fitted for January we quickly generate MAE to compare the Linear regression model and DNN.

# %%
y_pred_train = model_lregr.predict(X) # Note this is a fit!
y_pred_test_lr = model_lregr.predict(X_testing_df) # Note this is a test!

y_pred_test_dnn = model_dnn.predict(X_testing_df) #predicted values!!!, need to compute the residuals
mae_val_test_dnn = metrics.mean_absolute_error(y_test, y_pred_test_dnn) #MAE

mae_val_test_lr = metrics.mean_absolute_error(y_test, y_pred_test_lr) #MAE

print('Regression MAE: ',mae_val_test_lr)
print('DNN MAE: ',mae_val_test_dnn)
print('Difference in MAE in percentage', (mae_val_test_lr-mae_val_test_dnn)*100/mae_val_test_lr)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# Regression MAE:  1.079911327848354
# DNN MAE:  0.945275830654881
# Difference in MAE in percentage 12.467273351204186

# %% [markdown]
# ## 6.2. Compare models and predict for July and January
#
# To generate a full picture using training and testing data MAE and RMSEE for July and January using a pre-created function. To keep it simple we run it in  a loop using the model created earlier in the script.

# %%
list_models =[model_lregr,model_dnn]
list_model_names = ['reg_ols','dnn']
list_data_metrics=[]
i = 0
for model in list_models:
  model_name = list_model_names[i]
  if model_name =='dnn':
    epoch_val = epoch_n
  else:
    epoch_val=None
  selected_features = ['LST1','ELEV_SRTM','DISTOC'] #selected features
  selected_target = ['T1'] #selected dependent variables

  metrics_jan_df = model_predict_assessement(model=model,
                                          data_df=avg_jan_df,
                                          selected_features = selected_features,
                                          selected_target = selected_target,
                                          prop=0.3,
                                          random_seed=random_seed,
                                          epoch_val=epoch_val,
                                          out_dir=out_dir)
  
  selected_features = ['LST7','ELEV_SRTM','DISTOC'] #selected features
  selected_target = ['T7'] #selected dependent variables

  metrics_jul_df = model_predict_assessement(model=model,
                                          data_df=avg_jul_df,
                                          selected_features = selected_features,
                                          selected_target = selected_target,
                                          prop=0.3,
                                          random_seed=random_seed,
                                          epoch_val=epoch_val,
                                          out_dir=out_dir
                                          )
  metrics_jan_df['month']='jan'
  metrics_jul_df['month']='jul'
  metrics_jan_df['model']=model_name
  metrics_jul_df['model']=model_name
  
  data_metrics = pd.concat([metrics_jan_df,metrics_jul_df])
  list_data_metrics.append(data_metrics)
  i=i+1
# Out:
# Epoch 1/600
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0730 - mae: 1.0565
# Epoch 2/600
# 1/4 [======>.......................] - ETA: 0s - loss: 1.9677 - mae: 0.9084
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# 4/4 [==============================] - 0s 10ms/step - loss: 2.0729 - mae: 1.0563
# Epoch 3/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0747 - mae: 1.0593
# Epoch 4/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0755 - mae: 1.0568
# Epoch 5/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0707 - mae: 1.0562
# Epoch 6/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0701 - mae: 1.0559
# Epoch 7/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0763 - mae: 1.0579
# Epoch 8/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0775 - mae: 1.0595
# Epoch 9/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0684 - mae: 1.0583
# Epoch 10/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0733 - mae: 1.0558
# Epoch 11/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0743 - mae: 1.0555
# Epoch 12/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0712 - mae: 1.0549
# Epoch 13/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0717 - mae: 1.0557
# Epoch 14/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0707 - mae: 1.0591
# Epoch 15/600
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0704 - mae: 1.0586
# Epoch 16/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0661 - mae: 1.0568
# Epoch 17/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0755 - mae: 1.0583
# Epoch 18/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0716 - mae: 1.0578
# Epoch 19/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0727 - mae: 1.0537
# Epoch 20/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0702 - mae: 1.0535
# Epoch 21/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0638 - mae: 1.0554
# Epoch 22/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0653 - mae: 1.0573
# Epoch 23/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0657 - mae: 1.0575
# Epoch 24/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0654 - mae: 1.0569
# Epoch 25/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0628 - mae: 1.0554
# Epoch 26/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0630 - mae: 1.0547
# Epoch 27/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0629 - mae: 1.0539
# Epoch 28/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0620 - mae: 1.0534
# Epoch 29/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0622 - mae: 1.0548
# Epoch 30/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0620 - mae: 1.0551
# Epoch 31/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0666 - mae: 1.0543
# Epoch 32/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0605 - mae: 1.0527
# Epoch 33/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0663 - mae: 1.0558
# Epoch 34/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0606 - mae: 1.0544
# Epoch 35/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0603 - mae: 1.0548
# Epoch 36/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0674 - mae: 1.0549
# Epoch 37/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0596 - mae: 1.0525
# Epoch 38/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0605 - mae: 1.0544
# Epoch 39/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0589 - mae: 1.0530
# Epoch 40/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0633 - mae: 1.0576
# Epoch 41/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0591 - mae: 1.0541
# Epoch 42/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0568 - mae: 1.0538
# Epoch 43/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0558 - mae: 1.0520
# Epoch 44/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0561 - mae: 1.0523
# Epoch 45/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0562 - mae: 1.0520
# Epoch 46/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0637 - mae: 1.0540
# Epoch 47/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0576 - mae: 1.0541
# Epoch 48/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0568 - mae: 1.0534
# Epoch 49/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0544 - mae: 1.0516
# Epoch 50/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0559 - mae: 1.0516
# Epoch 51/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0603 - mae: 1.0527
# Epoch 52/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0548 - mae: 1.0524
# Epoch 53/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0545 - mae: 1.0531
# Epoch 54/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0625 - mae: 1.0533
# Epoch 55/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0547 - mae: 1.0522
# Epoch 56/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0540 - mae: 1.0529
# Epoch 57/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0556 - mae: 1.0537
# Epoch 58/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0538 - mae: 1.0528
# Epoch 59/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0526 - mae: 1.0528
# Epoch 60/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0555 - mae: 1.0522
# Epoch 61/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0502 - mae: 1.0502
# Epoch 62/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0612 - mae: 1.0535
# Epoch 63/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0535 - mae: 1.0533
# Epoch 64/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0505 - mae: 1.0520
# Epoch 65/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0508 - mae: 1.0500
# Epoch 66/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0495 - mae: 1.0503
# Epoch 67/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0498 - mae: 1.0500
# Epoch 68/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0498 - mae: 1.0493
# Epoch 69/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0488 - mae: 1.0504
# Epoch 70/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0490 - mae: 1.0504
# Epoch 71/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0467 - mae: 1.0502
# Epoch 72/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0473 - mae: 1.0503
# Epoch 73/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0518 - mae: 1.0514
# Epoch 74/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0577 - mae: 1.0518
# Epoch 75/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0450 - mae: 1.0497
# Epoch 76/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0545 - mae: 1.0526
# Epoch 77/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0496 - mae: 1.0527
# Epoch 78/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0478 - mae: 1.0515
# Epoch 79/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0490 - mae: 1.0502
# Epoch 80/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0458 - mae: 1.0479
# Epoch 81/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0467 - mae: 1.0488
# Epoch 82/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0465 - mae: 1.0490
# Epoch 83/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0463 - mae: 1.0491
# Epoch 84/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0433 - mae: 1.0491
# Epoch 85/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0498 - mae: 1.0513
# Epoch 86/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0445 - mae: 1.0499
# Epoch 87/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0445 - mae: 1.0501
# Epoch 88/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0428 - mae: 1.0498
# Epoch 89/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0414 - mae: 1.0490
# Epoch 90/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0400 - mae: 1.0483
# Epoch 91/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0482 - mae: 1.0524
# Epoch 92/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0443 - mae: 1.0500
# Epoch 93/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0405 - mae: 1.0480
# Epoch 94/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0408 - mae: 1.0479
# Epoch 95/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0413 - mae: 1.0477
# Epoch 96/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0448 - mae: 1.0488
# Epoch 97/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0435 - mae: 1.0506
# Epoch 98/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0403 - mae: 1.0495
# Epoch 99/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0398 - mae: 1.0488
# Epoch 100/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0527 - mae: 1.0518
# Epoch 101/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0442 - mae: 1.0464
# Epoch 102/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0439 - mae: 1.0470
# Epoch 103/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0391 - mae: 1.0481
# Epoch 104/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0391 - mae: 1.0481
# Epoch 105/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0387 - mae: 1.0482
# Epoch 106/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0364 - mae: 1.0473
# Epoch 107/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0466 - mae: 1.0491
# Epoch 108/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0370 - mae: 1.0460
# Epoch 109/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0353 - mae: 1.0464
# Epoch 110/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0349 - mae: 1.0470
# Epoch 111/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0347 - mae: 1.0479
# Epoch 112/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0361 - mae: 1.0479
# Epoch 113/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0352 - mae: 1.0483
# Epoch 114/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0395 - mae: 1.0486
# Epoch 115/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0340 - mae: 1.0456
# Epoch 116/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0344 - mae: 1.0465
# Epoch 117/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0341 - mae: 1.0469
# Epoch 118/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0317 - mae: 1.0461
# Epoch 119/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0382 - mae: 1.0475
# Epoch 120/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0363 - mae: 1.0468
# Epoch 121/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0335 - mae: 1.0470
# Epoch 122/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0325 - mae: 1.0466
# Epoch 123/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0313 - mae: 1.0454
# Epoch 124/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0305 - mae: 1.0453
# Epoch 125/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0307 - mae: 1.0452
# Epoch 126/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0310 - mae: 1.0456
# Epoch 127/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0335 - mae: 1.0464
# Epoch 128/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0367 - mae: 1.0486
# Epoch 129/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0339 - mae: 1.0457
# Epoch 130/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0341 - mae: 1.0449
# Epoch 131/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0328 - mae: 1.0453
# Epoch 132/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0284 - mae: 1.0441
# Epoch 133/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0278 - mae: 1.0444
# Epoch 134/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0284 - mae: 1.0446
# Epoch 135/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0329 - mae: 1.0474
# Epoch 136/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0286 - mae: 1.0459
# Epoch 137/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0288 - mae: 1.0445
# Epoch 138/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0287 - mae: 1.0436
# Epoch 139/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0259 - mae: 1.0427
# Epoch 140/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0281 - mae: 1.0453
# Epoch 141/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0279 - mae: 1.0449
# Epoch 142/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0296 - mae: 1.0452
# Epoch 143/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0316 - mae: 1.0452
# Epoch 144/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0261 - mae: 1.0438
# Epoch 145/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0242 - mae: 1.0437
# Epoch 146/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0353 - mae: 1.0454
# Epoch 147/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0232 - mae: 1.0442
# Epoch 148/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0245 - mae: 1.0447
# Epoch 149/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0261 - mae: 1.0450
# Epoch 150/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0324 - mae: 1.0456
# Epoch 151/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0254 - mae: 1.0421
# Epoch 152/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0271 - mae: 1.0460
# Epoch 153/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0248 - mae: 1.0435
# Epoch 154/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0252 - mae: 1.0426
# Epoch 155/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0271 - mae: 1.0426
# Epoch 156/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0341 - mae: 1.0469
# Epoch 157/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0233 - mae: 1.0441
# Epoch 158/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0194 - mae: 1.0429
# Epoch 159/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0386 - mae: 1.0435
# Epoch 160/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0300 - mae: 1.0430
# Epoch 161/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0200 - mae: 1.0431
# Epoch 162/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0306 - mae: 1.0460
# Epoch 163/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0237 - mae: 1.0428
# Epoch 164/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0228 - mae: 1.0443
# Epoch 165/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0249 - mae: 1.0442
# Epoch 166/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0189 - mae: 1.0427
# Epoch 167/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0225 - mae: 1.0430
# Epoch 168/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0192 - mae: 1.0433
# Epoch 169/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0246 - mae: 1.0428
# Epoch 170/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0213 - mae: 1.0418
# Epoch 171/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0165 - mae: 1.0419
# Epoch 172/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0167 - mae: 1.0421
# Epoch 173/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0191 - mae: 1.0429
# Epoch 174/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0179 - mae: 1.0434
# Epoch 175/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0200 - mae: 1.0417
# Epoch 176/600
# 4/4 [==============================] - 0s 10ms/step - loss: 2.0180 - mae: 1.0414
# Epoch 177/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0149 - mae: 1.0409
# Epoch 178/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0152 - mae: 1.0413
# Epoch 179/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0291 - mae: 1.0457
# Epoch 180/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0167 - mae: 1.0431
# Epoch 181/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0178 - mae: 1.0418
# Epoch 182/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0250 - mae: 1.0424
# Epoch 183/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0173 - mae: 1.0399
# Epoch 184/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0155 - mae: 1.0399
# Epoch 185/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0185 - mae: 1.0414
# Epoch 186/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0128 - mae: 1.0415
# Epoch 187/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0130 - mae: 1.0419
# Epoch 188/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0143 - mae: 1.0424
# Epoch 189/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0155 - mae: 1.0425
# Epoch 190/600
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0130 - mae: 1.0404
# Epoch 191/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0134 - mae: 1.0407
# Epoch 192/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0202 - mae: 1.0416
# Epoch 193/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0116 - mae: 1.0402
# Epoch 194/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0136 - mae: 1.0410
# Epoch 195/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0111 - mae: 1.0411
# Epoch 196/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0102 - mae: 1.0402
# Epoch 197/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0214 - mae: 1.0433
# Epoch 198/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0112 - mae: 1.0388
# Epoch 199/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0083 - mae: 1.0400
# Epoch 200/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0072 - mae: 1.0399
# Epoch 201/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0129 - mae: 1.0423
# Epoch 202/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0067 - mae: 1.0418
# Epoch 203/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0061 - mae: 1.0412
# Epoch 204/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0097 - mae: 1.0426
# Epoch 205/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0078 - mae: 1.0400
# Epoch 206/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0060 - mae: 1.0391
# Epoch 207/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0097 - mae: 1.0406
# Epoch 208/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0048 - mae: 1.0406
# Epoch 209/600
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0041 - mae: 1.0395
# Epoch 210/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0010 - mae: 1.0400
# Epoch 211/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0041 - mae: 1.0402
# Epoch 212/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9963 - mae: 1.0376
# Epoch 213/600
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0010 - mae: 1.0380
# Epoch 214/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9951 - mae: 1.0385
# Epoch 215/600
# 4/4 [==============================] - 0s 8ms/step - loss: 1.9935 - mae: 1.0374
# Epoch 216/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9943 - mae: 1.0373
# Epoch 217/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9961 - mae: 1.0385
# Epoch 218/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9892 - mae: 1.0364
# Epoch 219/600
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0037 - mae: 1.0403
# Epoch 220/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9906 - mae: 1.0378
# Epoch 221/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9854 - mae: 1.0355
# Epoch 222/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9862 - mae: 1.0364
# Epoch 223/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9858 - mae: 1.0363
# Epoch 224/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9866 - mae: 1.0369
# Epoch 225/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9839 - mae: 1.0350
# Epoch 226/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9829 - mae: 1.0340
# Epoch 227/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9857 - mae: 1.0356
# Epoch 228/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9841 - mae: 1.0340
# Epoch 229/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9921 - mae: 1.0375
# Epoch 230/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9803 - mae: 1.0328
# Epoch 231/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9809 - mae: 1.0336
# Epoch 232/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9832 - mae: 1.0349
# Epoch 233/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9821 - mae: 1.0347
# Epoch 234/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9801 - mae: 1.0332
# Epoch 235/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9824 - mae: 1.0349
# Epoch 236/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9831 - mae: 1.0340
# Epoch 237/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9776 - mae: 1.0328
# Epoch 238/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9834 - mae: 1.0352
# Epoch 239/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9807 - mae: 1.0353
# Epoch 240/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9794 - mae: 1.0331
# Epoch 241/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9874 - mae: 1.0370
# Epoch 242/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9882 - mae: 1.0360
# Epoch 243/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9773 - mae: 1.0313
# Epoch 244/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9779 - mae: 1.0324
# Epoch 245/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9782 - mae: 1.0315
# Epoch 246/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9787 - mae: 1.0339
# Epoch 247/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9763 - mae: 1.0333
# Epoch 248/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9745 - mae: 1.0321
# Epoch 249/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9745 - mae: 1.0315
# Epoch 250/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9751 - mae: 1.0313
# Epoch 251/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9760 - mae: 1.0314
# Epoch 252/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9727 - mae: 1.0314
# Epoch 253/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9753 - mae: 1.0310
# Epoch 254/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9729 - mae: 1.0309
# Epoch 255/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9803 - mae: 1.0330
# Epoch 256/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9815 - mae: 1.0326
# Epoch 257/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9722 - mae: 1.0293
# Epoch 258/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9792 - mae: 1.0313
# Epoch 259/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9725 - mae: 1.0319
# Epoch 260/600
# 4/4 [==============================] - 0s 9ms/step - loss: 1.9707 - mae: 1.0313
# Epoch 261/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9710 - mae: 1.0298
# Epoch 262/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9709 - mae: 1.0297
# Epoch 263/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9728 - mae: 1.0296
# Epoch 264/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9695 - mae: 1.0300
# Epoch 265/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9697 - mae: 1.0303
# Epoch 266/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9691 - mae: 1.0301
# Epoch 267/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9736 - mae: 1.0315
# Epoch 268/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9712 - mae: 1.0308
# Epoch 269/600
# 4/4 [==============================] - 0s 8ms/step - loss: 1.9689 - mae: 1.0299
# Epoch 270/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9683 - mae: 1.0303
# Epoch 271/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9688 - mae: 1.0312
# Epoch 272/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9678 - mae: 1.0307
# Epoch 273/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9689 - mae: 1.0302
# Epoch 274/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9694 - mae: 1.0297
# Epoch 275/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9683 - mae: 1.0280
# Epoch 276/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9691 - mae: 1.0282
# Epoch 277/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9701 - mae: 1.0297
# Epoch 278/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9670 - mae: 1.0305
# Epoch 279/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9749 - mae: 1.0305
# Epoch 280/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9708 - mae: 1.0296
# Epoch 281/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9660 - mae: 1.0293
# Epoch 282/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9660 - mae: 1.0283
# Epoch 283/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9658 - mae: 1.0287
# Epoch 284/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9660 - mae: 1.0293
# Epoch 285/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9658 - mae: 1.0273
# Epoch 286/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9682 - mae: 1.0271
# Epoch 287/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9673 - mae: 1.0276
# Epoch 288/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9644 - mae: 1.0271
# Epoch 289/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9667 - mae: 1.0298
# Epoch 290/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9641 - mae: 1.0280
# Epoch 291/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9612 - mae: 1.0275
# Epoch 292/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9640 - mae: 1.0286
# Epoch 293/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9626 - mae: 1.0269
# Epoch 294/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9677 - mae: 1.0294
# Epoch 295/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9642 - mae: 1.0270
# Epoch 296/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9611 - mae: 1.0266
# Epoch 297/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9616 - mae: 1.0275
# Epoch 298/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9629 - mae: 1.0289
# Epoch 299/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9603 - mae: 1.0282
# Epoch 300/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9599 - mae: 1.0264
# Epoch 301/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9620 - mae: 1.0258
# Epoch 302/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9643 - mae: 1.0268
# Epoch 303/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9710 - mae: 1.0322
# Epoch 304/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9665 - mae: 1.0302
# Epoch 305/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9615 - mae: 1.0252
# Epoch 306/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9614 - mae: 1.0257
# Epoch 307/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9589 - mae: 1.0263
# Epoch 308/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9606 - mae: 1.0262
# Epoch 309/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9593 - mae: 1.0262
# Epoch 310/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9616 - mae: 1.0261
# Epoch 311/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9581 - mae: 1.0265
# Epoch 312/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9605 - mae: 1.0273
# Epoch 313/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9562 - mae: 1.0259
# Epoch 314/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9608 - mae: 1.0268
# Epoch 315/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9621 - mae: 1.0259
# Epoch 316/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9565 - mae: 1.0256
# Epoch 317/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9591 - mae: 1.0278
# Epoch 318/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9628 - mae: 1.0258
# Epoch 319/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9547 - mae: 1.0249
# Epoch 320/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9548 - mae: 1.0256
# Epoch 321/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9584 - mae: 1.0271
# Epoch 322/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9570 - mae: 1.0267
# Epoch 323/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9650 - mae: 1.0269
# Epoch 324/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9549 - mae: 1.0240
# Epoch 325/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9569 - mae: 1.0244
# Epoch 326/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9604 - mae: 1.0238
# Epoch 327/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9564 - mae: 1.0222
# Epoch 328/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9526 - mae: 1.0230
# Epoch 329/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9576 - mae: 1.0257
# Epoch 330/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9556 - mae: 1.0274
# Epoch 331/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9551 - mae: 1.0272
# Epoch 332/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9602 - mae: 1.0256
# Epoch 333/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9568 - mae: 1.0247
# Epoch 334/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9529 - mae: 1.0238
# Epoch 335/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9527 - mae: 1.0248
# Epoch 336/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9570 - mae: 1.0260
# Epoch 337/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9548 - mae: 1.0252
# Epoch 338/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9554 - mae: 1.0245
# Epoch 339/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9576 - mae: 1.0252
# Epoch 340/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9621 - mae: 1.0246
# Epoch 341/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9564 - mae: 1.0232
# Epoch 342/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9526 - mae: 1.0235
# Epoch 343/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9539 - mae: 1.0242
# Epoch 344/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9529 - mae: 1.0235
# Epoch 345/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9511 - mae: 1.0220
# Epoch 346/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9521 - mae: 1.0220
# Epoch 347/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9580 - mae: 1.0237
# Epoch 348/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9498 - mae: 1.0213
# Epoch 349/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9475 - mae: 1.0220
# Epoch 350/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9520 - mae: 1.0256
# Epoch 351/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9558 - mae: 1.0272
# Epoch 352/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9525 - mae: 1.0253
# Epoch 353/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9523 - mae: 1.0221
# Epoch 354/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9530 - mae: 1.0216
# Epoch 355/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9511 - mae: 1.0209
# Epoch 356/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9499 - mae: 1.0231
# Epoch 357/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9528 - mae: 1.0249
# Epoch 358/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9494 - mae: 1.0240
# Epoch 359/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9485 - mae: 1.0234
# Epoch 360/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9482 - mae: 1.0242
# Epoch 361/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9493 - mae: 1.0219
# Epoch 362/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9505 - mae: 1.0213
# Epoch 363/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9479 - mae: 1.0204
# Epoch 364/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9469 - mae: 1.0214
# Epoch 365/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9568 - mae: 1.0264
# Epoch 366/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9472 - mae: 1.0236
# Epoch 367/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9461 - mae: 1.0226
# Epoch 368/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9541 - mae: 1.0235
# Epoch 369/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9548 - mae: 1.0216
# Epoch 370/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9577 - mae: 1.0230
# Epoch 371/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9596 - mae: 1.0264
# Epoch 372/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9531 - mae: 1.0262
# Epoch 373/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9496 - mae: 1.0251
# Epoch 374/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9504 - mae: 1.0222
# Epoch 375/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9520 - mae: 1.0208
# Epoch 376/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9501 - mae: 1.0210
# Epoch 377/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9483 - mae: 1.0218
# Epoch 378/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9457 - mae: 1.0256
# Epoch 379/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9536 - mae: 1.0274
# Epoch 380/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9464 - mae: 1.0249
# Epoch 381/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9430 - mae: 1.0192
# Epoch 382/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9532 - mae: 1.0217
# Epoch 383/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9496 - mae: 1.0211
# Epoch 384/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9475 - mae: 1.0217
# Epoch 385/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9551 - mae: 1.0261
# Epoch 386/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9454 - mae: 1.0237
# Epoch 387/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9465 - mae: 1.0223
# Epoch 388/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9456 - mae: 1.0198
# Epoch 389/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9458 - mae: 1.0198
# Epoch 390/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9418 - mae: 1.0197
# Epoch 391/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9412 - mae: 1.0211
# Epoch 392/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9421 - mae: 1.0219
# Epoch 393/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9437 - mae: 1.0218
# Epoch 394/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9410 - mae: 1.0202
# Epoch 395/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9413 - mae: 1.0215
# Epoch 396/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9416 - mae: 1.0216
# Epoch 397/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9436 - mae: 1.0210
# Epoch 398/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9416 - mae: 1.0210
# Epoch 399/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9428 - mae: 1.0213
# Epoch 400/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9393 - mae: 1.0176
# Epoch 401/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9469 - mae: 1.0195
# Epoch 402/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9414 - mae: 1.0186
# Epoch 403/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9426 - mae: 1.0223
# Epoch 404/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9420 - mae: 1.0203
# Epoch 405/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9409 - mae: 1.0208
# Epoch 406/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9452 - mae: 1.0221
# Epoch 407/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9422 - mae: 1.0208
# Epoch 408/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9492 - mae: 1.0188
# Epoch 409/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9466 - mae: 1.0227
# Epoch 410/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9400 - mae: 1.0197
# Epoch 411/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9388 - mae: 1.0194
# Epoch 412/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9541 - mae: 1.0265
# Epoch 413/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9475 - mae: 1.0212
# Epoch 414/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9420 - mae: 1.0202
# Epoch 415/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9387 - mae: 1.0206
# Epoch 416/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9365 - mae: 1.0198
# Epoch 417/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9381 - mae: 1.0185
# Epoch 418/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9371 - mae: 1.0182
# Epoch 419/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9371 - mae: 1.0204
# Epoch 420/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9382 - mae: 1.0209
# Epoch 421/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9370 - mae: 1.0193
# Epoch 422/600
# 4/4 [==============================] - 0s 8ms/step - loss: 1.9392 - mae: 1.0203
# Epoch 423/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9446 - mae: 1.0197
# Epoch 424/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9435 - mae: 1.0184
# Epoch 425/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9373 - mae: 1.0208
# Epoch 426/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9351 - mae: 1.0190
# Epoch 427/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9354 - mae: 1.0184
# Epoch 428/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9366 - mae: 1.0189
# Epoch 429/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9360 - mae: 1.0193
# Epoch 430/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9356 - mae: 1.0186
# Epoch 431/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9382 - mae: 1.0196
# Epoch 432/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9447 - mae: 1.0206
# Epoch 433/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9337 - mae: 1.0175
# Epoch 434/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9374 - mae: 1.0183
# Epoch 435/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9375 - mae: 1.0185
# Epoch 436/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9357 - mae: 1.0178
# Epoch 437/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9364 - mae: 1.0199
# Epoch 438/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9342 - mae: 1.0191
# Epoch 439/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9335 - mae: 1.0190
# Epoch 440/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9386 - mae: 1.0204
# Epoch 441/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9364 - mae: 1.0188
# Epoch 442/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9493 - mae: 1.0172
# Epoch 443/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9430 - mae: 1.0177
# Epoch 444/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9304 - mae: 1.0135
# Epoch 445/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9458 - mae: 1.0202
# Epoch 446/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9436 - mae: 1.0249
# Epoch 447/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9508 - mae: 1.0198
# Epoch 448/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9359 - mae: 1.0165
# Epoch 449/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9334 - mae: 1.0167
# Epoch 450/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9329 - mae: 1.0180
# Epoch 451/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9348 - mae: 1.0198
# Epoch 452/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9483 - mae: 1.0216
# Epoch 453/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9350 - mae: 1.0186
# Epoch 454/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9325 - mae: 1.0197
# Epoch 455/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9349 - mae: 1.0191
# Epoch 456/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9301 - mae: 1.0170
# Epoch 457/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9302 - mae: 1.0165
# Epoch 458/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9334 - mae: 1.0182
# Epoch 459/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9303 - mae: 1.0165
# Epoch 460/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9296 - mae: 1.0158
# Epoch 461/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9319 - mae: 1.0163
# Epoch 462/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9322 - mae: 1.0174
# Epoch 463/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9393 - mae: 1.0191
# Epoch 464/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9316 - mae: 1.0161
# Epoch 465/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9301 - mae: 1.0157
# Epoch 466/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9276 - mae: 1.0161
# Epoch 467/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9296 - mae: 1.0174
# Epoch 468/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9290 - mae: 1.0176
# Epoch 469/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9289 - mae: 1.0169
# Epoch 470/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9287 - mae: 1.0164
# Epoch 471/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9340 - mae: 1.0176
# Epoch 472/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9289 - mae: 1.0173
# Epoch 473/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9308 - mae: 1.0165
# Epoch 474/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9290 - mae: 1.0155
# Epoch 475/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9284 - mae: 1.0158
# Epoch 476/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9294 - mae: 1.0189
# Epoch 477/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9302 - mae: 1.0192
# Epoch 478/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9271 - mae: 1.0163
# Epoch 479/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9275 - mae: 1.0161
# Epoch 480/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9304 - mae: 1.0164
# Epoch 481/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9330 - mae: 1.0171
# Epoch 482/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9286 - mae: 1.0170
# Epoch 483/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9308 - mae: 1.0181
# Epoch 484/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9246 - mae: 1.0161
# Epoch 485/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9256 - mae: 1.0148
# Epoch 486/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9286 - mae: 1.0141
# Epoch 487/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9264 - mae: 1.0152
# Epoch 488/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9265 - mae: 1.0170
# Epoch 489/600
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9273 - mae: 1.0174
# Epoch 490/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9249 - mae: 1.0164
# Epoch 491/600
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9254 - mae: 1.0158
# Epoch 492/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9315 - mae: 1.0169
# Epoch 493/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9265 - mae: 1.0170
# Epoch 494/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9240 - mae: 1.0164
# Epoch 495/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9276 - mae: 1.0162
# Epoch 496/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9281 - mae: 1.0161
# Epoch 497/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9301 - mae: 1.0187
# Epoch 498/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9271 - mae: 1.0163
# Epoch 499/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9236 - mae: 1.0137
# Epoch 500/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9249 - mae: 1.0134
# Epoch 501/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9272 - mae: 1.0144
# Epoch 502/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9283 - mae: 1.0150
# Epoch 503/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9255 - mae: 1.0159
# Epoch 504/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9234 - mae: 1.0155
# Epoch 505/600
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9235 - mae: 1.0164
# Epoch 506/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9368 - mae: 1.0193
# Epoch 507/600
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9275 - mae: 1.0161
# Epoch 508/600
# ...
# Epoch 432/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2396 - mae: 2.0439
# Epoch 433/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2450 - mae: 2.0450
# Epoch 434/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2476 - mae: 2.0456
# Epoch 435/600
# 4/4 [==============================] - 0s 8ms/step - loss: 6.2352 - mae: 2.0429
# Epoch 436/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2398 - mae: 2.0439
# Epoch 437/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2359 - mae: 2.0435
# Epoch 438/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2381 - mae: 2.0442
# Epoch 439/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2362 - mae: 2.0441
# Epoch 440/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2392 - mae: 2.0446
# Epoch 441/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2359 - mae: 2.0439
# Epoch 442/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2348 - mae: 2.0431
# Epoch 443/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2712 - mae: 2.0494
# Epoch 444/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2379 - mae: 2.0417
# Epoch 445/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2335 - mae: 2.0425
# Epoch 446/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2450 - mae: 2.0451
# Epoch 447/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2361 - mae: 2.0431
# Epoch 448/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2327 - mae: 2.0432
# Epoch 449/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2319 - mae: 2.0432
# Epoch 450/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2334 - mae: 2.0436
# Epoch 451/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2342 - mae: 2.0442
# Epoch 452/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2346 - mae: 2.0433
# Epoch 453/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2302 - mae: 2.0427
# Epoch 454/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2339 - mae: 2.0432
# Epoch 455/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2365 - mae: 2.0434
# Epoch 456/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2384 - mae: 2.0439
# Epoch 457/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2382 - mae: 2.0430
# Epoch 458/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2281 - mae: 2.0420
# Epoch 459/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2317 - mae: 2.0424
# Epoch 460/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2269 - mae: 2.0421
# Epoch 461/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2339 - mae: 2.0438
# Epoch 462/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2545 - mae: 2.0461
# Epoch 463/600
# 4/4 [==============================] - 0s 8ms/step - loss: 6.2373 - mae: 2.0445
# Epoch 464/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2272 - mae: 2.0419
# Epoch 465/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2357 - mae: 2.0432
# Epoch 466/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2297 - mae: 2.0415
# Epoch 467/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2292 - mae: 2.0420
# Epoch 468/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2494 - mae: 2.0457
# Epoch 469/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2334 - mae: 2.0432
# Epoch 470/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2255 - mae: 2.0420
# Epoch 471/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2264 - mae: 2.0421
# Epoch 472/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2240 - mae: 2.0414
# Epoch 473/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2288 - mae: 2.0412
# Epoch 474/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2269 - mae: 2.0410
# Epoch 475/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2337 - mae: 2.0435
# Epoch 476/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2263 - mae: 2.0418
# Epoch 477/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2276 - mae: 2.0419
# Epoch 478/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2246 - mae: 2.0423
# Epoch 479/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2270 - mae: 2.0418
# Epoch 480/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2280 - mae: 2.0422
# Epoch 481/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2461 - mae: 2.0466
# Epoch 482/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2237 - mae: 2.0416
# Epoch 483/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2220 - mae: 2.0411
# Epoch 484/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2343 - mae: 2.0420
# Epoch 485/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2298 - mae: 2.0410
# Epoch 486/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2226 - mae: 2.0410
# Epoch 487/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2213 - mae: 2.0407
# Epoch 488/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2207 - mae: 2.0407
# Epoch 489/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2279 - mae: 2.0421
# Epoch 490/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2232 - mae: 2.0414
# Epoch 491/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2198 - mae: 2.0408
# Epoch 492/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2197 - mae: 2.0400
# Epoch 493/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2238 - mae: 2.0414
# Epoch 494/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2269 - mae: 2.0411
# Epoch 495/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2273 - mae: 2.0424
# Epoch 496/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2195 - mae: 2.0401
# Epoch 497/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2218 - mae: 2.0409
# Epoch 498/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2184 - mae: 2.0408
# Epoch 499/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2188 - mae: 2.0402
# Epoch 500/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2202 - mae: 2.0398
# Epoch 501/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2213 - mae: 2.0407
# Epoch 502/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2193 - mae: 2.0407
# Epoch 503/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2175 - mae: 2.0396
# Epoch 504/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2203 - mae: 2.0397
# Epoch 505/600
# 4/4 [==============================] - 0s 8ms/step - loss: 6.2177 - mae: 2.0403
# Epoch 506/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2212 - mae: 2.0401
# Epoch 507/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2347 - mae: 2.0426
# Epoch 508/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2184 - mae: 2.0395
# Epoch 509/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2148 - mae: 2.0395
# Epoch 510/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2200 - mae: 2.0407
# Epoch 511/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2207 - mae: 2.0409
# Epoch 512/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2236 - mae: 2.0421
# Epoch 513/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2167 - mae: 2.0401
# Epoch 514/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2184 - mae: 2.0402
# Epoch 515/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2221 - mae: 2.0400
# Epoch 516/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2305 - mae: 2.0426
# Epoch 517/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2210 - mae: 2.0394
# Epoch 518/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2241 - mae: 2.0408
# Epoch 519/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2146 - mae: 2.0401
# Epoch 520/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2199 - mae: 2.0407
# Epoch 521/600
# 4/4 [==============================] - 0s 8ms/step - loss: 6.2156 - mae: 2.0398
# Epoch 522/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2140 - mae: 2.0395
# Epoch 523/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2119 - mae: 2.0389
# Epoch 524/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2118 - mae: 2.0384
# Epoch 525/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2143 - mae: 2.0387
# Epoch 526/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2176 - mae: 2.0405
# Epoch 527/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2295 - mae: 2.0409
# Epoch 528/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2190 - mae: 2.0387
# Epoch 529/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2158 - mae: 2.0391
# Epoch 530/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2148 - mae: 2.0396
# Epoch 531/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2129 - mae: 2.0396
# Epoch 532/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2167 - mae: 2.0387
# Epoch 533/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2112 - mae: 2.0391
# Epoch 534/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2099 - mae: 2.0391
# Epoch 535/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2167 - mae: 2.0388
# Epoch 536/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2147 - mae: 2.0388
# Epoch 537/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2129 - mae: 2.0385
# Epoch 538/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2134 - mae: 2.0382
# Epoch 539/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2113 - mae: 2.0385
# Epoch 540/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2175 - mae: 2.0400
# Epoch 541/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2086 - mae: 2.0390
# Epoch 542/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2079 - mae: 2.0381
# Epoch 543/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2157 - mae: 2.0388
# Epoch 544/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2172 - mae: 2.0389
# Epoch 545/600
# 4/4 [==============================] - 0s 10ms/step - loss: 6.2071 - mae: 2.0376
# Epoch 546/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2136 - mae: 2.0397
# Epoch 547/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2113 - mae: 2.0395
# Epoch 548/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2178 - mae: 2.0397
# Epoch 549/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2102 - mae: 2.0381
# Epoch 550/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2099 - mae: 2.0385
# Epoch 551/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2075 - mae: 2.0382
# Epoch 552/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2094 - mae: 2.0391
# Epoch 553/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2109 - mae: 2.0389
# Epoch 554/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2132 - mae: 2.0383
# Epoch 555/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2126 - mae: 2.0392
# Epoch 556/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2168 - mae: 2.0397
# Epoch 557/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2062 - mae: 2.0385
# Epoch 558/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2132 - mae: 2.0379
# Epoch 559/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2066 - mae: 2.0369
# Epoch 560/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2180 - mae: 2.0400
# Epoch 561/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2096 - mae: 2.0379
# Epoch 562/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2070 - mae: 2.0375
# Epoch 563/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2041 - mae: 2.0373
# Epoch 564/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2237 - mae: 2.0421
# Epoch 565/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2129 - mae: 2.0396
# Epoch 566/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2078 - mae: 2.0383
# Epoch 567/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2076 - mae: 2.0378
# Epoch 568/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2079 - mae: 2.0386
# Epoch 569/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2031 - mae: 2.0371
# Epoch 570/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2160 - mae: 2.0394
# Epoch 571/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2073 - mae: 2.0368
# Epoch 572/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2047 - mae: 2.0363
# Epoch 573/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2034 - mae: 2.0362
# Epoch 574/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2094 - mae: 2.0383
# Epoch 575/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2065 - mae: 2.0383
# Epoch 576/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2371 - mae: 2.0408
# Epoch 577/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2081 - mae: 2.0369
# Epoch 578/600
# 4/4 [==============================] - 0s 7ms/step - loss: 6.2040 - mae: 2.0366
# Epoch 579/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2047 - mae: 2.0380
# Epoch 580/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2083 - mae: 2.0385
# Epoch 581/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2160 - mae: 2.0406
# Epoch 582/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2183 - mae: 2.0386
# Epoch 583/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2057 - mae: 2.0374
# Epoch 584/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2145 - mae: 2.0399
# Epoch 585/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2073 - mae: 2.0388
# Epoch 586/600
# 4/4 [==============================] - 0s 6ms/step - loss: 6.2186 - mae: 2.0394
# Epoch 587/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2144 - mae: 2.0398
# Epoch 588/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2025 - mae: 2.0371
# Epoch 589/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2196 - mae: 2.0377
# Epoch 590/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2034 - mae: 2.0359
# Epoch 591/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.1999 - mae: 2.0360
# Epoch 592/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2006 - mae: 2.0362
# Epoch 593/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2032 - mae: 2.0369
# Epoch 594/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2052 - mae: 2.0382
# Epoch 595/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2094 - mae: 2.0391
# Epoch 596/600
# 4/4 [==============================] - 0s 5ms/step - loss: 6.2058 - mae: 2.0388
# Epoch 597/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2112 - mae: 2.0399
# Epoch 598/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2340 - mae: 2.0403
# Epoch 599/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2090 - mae: 2.0363
# Epoch 600/600
# 4/4 [==============================] - 0s 4ms/step - loss: 6.2018 - mae: 2.0346
# 4/4 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step

# %%
#combine all
data_metrics = pd.concat(list_data_metrics)
display(data_metrics)
# Out:
#         mae      rmse  test month    model
# 0  1.079911  1.403235     1   jan  reg_ols
# 1  1.138093  1.500918     0   jan  reg_ols
# 0  2.617082  3.372889     1   jul  reg_ols
# 1  2.022044  2.480021     0   jul  reg_ols
# 0  0.873550  1.249394     1   jan      dnn
# 1  1.011060  1.381902     0   jan      dnn
# 0  2.624722  3.366027     1   jul      dnn
# 1  2.035626  2.489668     0   jul      dnn

# %% [markdown]
# # 7 Conclusions
#
# In this exercise, we predicted air temperature at stations located in Oregon using a dense neural network. We used several features including Land Surface Temperature from MODIS derived satellite imagery as well as the distance to ocean and elevation. We compared the dense neural network to a baseline model (Linear regression using OLS) for the month on January and July. Using the test data, we found a -0.20 C and 0.01 C difference in the MAE predicted temperatures in January and July respectively. From this short exercise, we can highlight a few interesting points:
#
# 1. **Improvements**: This is a modest improvement for the DNN for January. Improvements arising from Deep Neural Networks are often more visible when using more data and in more complext cases.
#
# 2. **Seasonality and error**: It is harder to predict in July than in January. A closer look at the temperature on the July LST layer will show more divergence in Summer compared to air temperature.
#
# 3. **Model complexity and architecture**: there is a trade off between model complexity and number of points available as well as the complexity of the problem. This is particularly true given that we only have 125 points for the fitting of the DNN model.
#
# This exercise was a useful gentle introduction to DNN and keras but more interesting use cases will follow in the course!

# %%
############################# END OF SCRIPT ###################################
